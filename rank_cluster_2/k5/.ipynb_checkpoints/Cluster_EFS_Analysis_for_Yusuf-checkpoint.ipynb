# %%
from ipynb.fs.full.CovidReceptorExpressionAnalysis_Functions import *

# %%
c1_patients = pd.read_csv('c1.txt',header=None)[0].tolist()
c2_patients = pd.read_csv('allpat.txt',header=None)[0].tolist()

for i in range(len(c1_patients)):
    c1_patients[i] = ('TARGET-30-' + c1_patients[i])
for i in range(len(c2_patients)):
    c2_patients[i] = ('TARGET-30-' + c2_patients [i])

c1_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c1_patients)]['Sample Identifier']
c2_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c2_patients)]['Sample Identifier']

# %%
compareEFS([c1_samples,c2_samples], 'EFS stratified by GSEA rank clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median EFS = 470.0, mean EFS = 1047.0, 95% CI = (713.9505140069841, 1380.0494859930159)
# Remaining: median EFS = 721.0, mean EFS = 1539.4696356275304, 95% CI = (1354.7937629686828, 1724.145508286378)
# Ttest_indResult(statistic=-2.190922806654685, pvalue=0.029242192452042272)

# %%
kaplanmeierEFS([c1_samples,c2_samples], 'Cluster', 'Remaining')

# %%
compareExpression('ACE2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.1743, mean = -0.006006122448979597, 95% CI = (-0.28639602334007125, 0.2743837784421121)
# Remaining: median = -0.0694, mean = -8.032128513926037e-07, 95% CI = (-0.12445874585833179, 0.124457139432629)
# Ttest_indResult(statistic=-0.038352521899989445, pvalue=0.9694324684916187)

# %%
compareExpression('TMPRSS2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.3547, mean = -0.35375510204081634, 95% CI = (-0.5885788187246812, -0.11893138535695152)
# Remaining: median = -0.0537, mean = 8.032128514073175e-07, 95% CI = (-0.12445711284165682, 0.12445871926735964)
# Ttest_indResult(statistic=-2.315946685447539, pvalue=0.021244349919390813)

# %%
compareExpression('IFITM2', [c1_samples,c2_samples], 'Clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median = -0.7787, mean = -0.7364408163265306, 95% CI = (-0.9880871615942395, -0.48479447105882173)
# Remaining: median = -0.0188, mean = 8.032128514073175e-07, 95% CI = (-0.12445700147940347, 0.1244586079051063)
# Ttest_indResult(statistic=-4.779135135673277, pvalue=2.7768462991347716e-06)

# %%
compareExpression('IFITM3',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.7427, mean = -0.768795918367347, 95% CI = (-1.0562737774060755, -0.48131805932861843)
# Remaining: median = 0.0543, mean = 3.614457831324011e-06, 95% CI = (-0.1244546564974439, 0.12446188541310656)
# Ttest_indResult(statistic=-4.889634928915721, pvalue=1.659728817207418e-06)

# %%
compareExpression('MYCN',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 1.6371, mean = 1.2697551020408162, 95% CI = (0.9976432496498736, 1.5418669544317587)
# Remaining: median = -0.2762, mean = -1.2048192771002754e-06, 95% CI = (-0.12445973523620298, 0.12445732559764879)
# Ttest_indResult(statistic=8.147654954149871, pvalue=1.0527267622271763e-14)

# %%
compareExpression('NTRK1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -1.2784, mean = -1.1252142857142857, 95% CI = (-1.2852001115866842, -0.9652284598418872)
# Remaining: median = 0.1392, mean = 1.2048192771127598e-06, 95% CI = (-0.12445668548141911, 0.12445909511997333)
# Ttest_indResult(statistic=-7.614082297180144, pvalue=3.5893313249786805e-13)

# %%
compareExpression('PTPN6',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.9451, mean = -0.9349163265306123, 95% CI = (-1.07487564668531, -0.7949570063759146)
# Remaining: median = -0.1149, mean = -4.417670682738463e-06, 95% CI = (-0.12446198867814715, 0.12445315333678167)
# Ttest_indResult(statistic=-6.370773968556148, pvalue=7.178722484922689e-10)

# %%
compareExpression('TP53',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 1.1374, mean = 1.1385673469387756, 95% CI = (0.9429349283224301, 1.3341997655551212)
# Remaining: median = -0.1481, mean = -2.0080321285236444e-06, 95% CI = (-0.12445963624128796, 0.12445562017703092)
# Ttest_indResult(statistic=7.593918960761663, pvalue=4.0892698891266806e-13)

# %%
compareExpression('CXCL10',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.8693, mean = -0.7063122448979592, 95% CI = (-0.9287582533333145, -0.4838662364626039)
# Remaining: median = -0.0646, mean = -2.008032128520077e-06, 95% CI = (-0.1244602001199337, 0.12445618405567666)
# Ttest_indResult(statistic=-4.652615907691951, pvalue=4.949209582617674e-06)

# %%
compareExpression('CXCL11',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.56, mean = -0.6701795918367345, 95% CI = (-0.9236819493020305, -0.4166772343714385)
# Remaining: median = -0.0556, mean = -1.6064257027968001e-06, 95% CI = (-0.12445983571338452, 0.12445662286197894)
# Ttest_indResult(statistic=-4.344773469449733, pvalue=1.9182070885936085e-05)

# %%
compareExpression('AGTR1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.1979, mean = -0.11287346938775511, 95% CI = (-0.296283271013817, 0.0705363322383068)
# Remaining: median = -0.2605, mean = 4.016064257018753e-07, 95% CI = (-0.12445733240726432, 0.12445813562011572)
# Ttest_indResult(statistic=-0.7567846948802234, pvalue=0.4497808018874325)

# %%
compareExpression('BSG',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.4095, mean = 0.23587551020408162, 95% CI = (-0.043834717679083285, 0.5155857380872465)
# Remaining: median = 0.0265, mean = 0.0, 95% CI = (-0.12445756868196209, 0.12445756868196209)
# Ttest_indResult(statistic=1.5069962694821548, pvalue=0.13287808474928814)
