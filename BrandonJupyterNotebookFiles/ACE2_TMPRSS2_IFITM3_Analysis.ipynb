# %%
from ipynb.fs.full.TARGET_Analysis_Functions import *
from ipynb.fs.full.ACE2_SCA_Analysis import *

# %% [markdown]
# # EFS Analysis

# %%
#ACE2
ACE2_groups = stratifyDataOnGeneExpression('ACE2',-0.5,0.5)
compareEFS2(ACE2_groups, 'EFS stratified by ACE2 expression', ['Low ACE2','High ACE2'], 't-test_ind')
kaplanmeierEFS(ACE2_groups,'Low ACE2','High ACE2')
# Out:
# Low ACE2 v.s. High ACE2: t-test independent samples, P_val=6.734e-02 stat=1.843e+00
# Low ACE2: median = 1297.0, mean = 1760.6623376623377, 95% CI = (1411.85408764956, 2109.4705876751154)
# High ACE2: median = 663.0, mean = 1329.5068493150684, 95% CI = (1035.567928128563, 1623.4457705015739)

# %%
#TMPRSS2
TMPRSS2_groups = stratifyDataOnGeneExpression('TMPRSS2',-0.5,0.5)
compareEFS2(TMPRSS2_groups, 'EFS stratified by TMPRSS2 expression', ['Low TMPRSS2','High TMPRSS2'], 't-test_ind')
kaplanmeierEFS(TMPRSS2_groups,'Low TMPRSS2','High TMPRSS2')
# Out:
# Low TMPRSS2 v.s. High TMPRSS2: t-test independent samples, P_val=7.598e-01 stat=3.064e-01
# Low TMPRSS2: median = 702.5, mean = 1559.4736842105262, 95% CI = (1215.1680713900803, 1903.7792970309722)
# High TMPRSS2: median = 686.0, mean = 1483.7285714285715, 95% CI = (1144.3425982359836, 1823.1145446211594)

# %%
#IFITM3
IFITM3_groups = stratifyDataOnGeneExpression('IFITM3',-0.5,0.5)
compareEFS2(IFITM3_groups, 'EFS stratified by IFITM3 expression', ['Low IFITM3','High IFITM3'], 't-test_ind')
kaplanmeierEFS(IFITM3_groups,'Low IFITM3','High IFITM3')
# Out:
# Low IFITM3 v.s. High IFITM3: t-test independent samples, P_val=5.003e-01 stat=6.757e-01
# Low IFITM3: median = 610.0, mean = 1428.2328767123288, 95% CI = (1094.8784769638505, 1761.587276460807)
# High IFITM3: median = 665.5, mean = 1279.5, 95% CI = (1003.3952276358932, 1555.6047723641068)

# %% [markdown]
# # MYCN Analysis

# %%
MYCN_groups = stratifyCategoricalSampleData('MYCN', 'Not Amplified', 'Amplified')
compareExpression2('ACE2', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
compareExpression2('TMPRSS2', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
compareExpression2('IFITM3', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=9.112e-02 stat=-1.696e+00
# Not Amplified: median = -0.0907, mean = -0.06035885714285715, 95% CI = (-0.20714595962903704, 0.08642824534332272)
# Amplified: median = 0.04875, mean = 0.1821661764705882, 95% CI = (-0.06155583010725574, 0.4258881830484321)
# Not Amplified v.s. Amplified: t-test independent samples, P_val=6.602e-01 stat=-4.401e-01
# Not Amplified: median = -0.0857, mean = -0.0336617142857143, 95% CI = (-0.18100088133095066, 0.11367745275952207)
# Amplified: median = 0.012750000000000001, mean = 0.029433823529411752, 95% CI = (-0.21429882306563774, 0.27316647012446127)
# Not Amplified v.s. Amplified: t-test independent samples, P_val=2.402e-06 stat=4.832e+00
# Not Amplified: median = 0.2448, mean = 0.17598514285714284, 95% CI = (0.04593926302526202, 0.30603102268902366)
# Amplified: median = -0.47245, mean = -0.4902926470588235, 95% CI = (-0.766222009077939, -0.21436328503970808)

# %%
geneScatter('ACE2','MYCN')
geneScatter('TMPRSS2','MYCN')
geneScatter('IFITM3','MYCN')
# Out:
# Pearson correlation coefficient = 0.013064730516041376
# p-value = 0.8374710289467292
# Pearson correlation coefficient = -0.09338525037695872
# p-value = 0.14172635422123744
# Pearson correlation coefficient = -0.3740288073684074
# p-value = 1.0941072984374612e-09

# %% [markdown]
# # SCA Analysis

# %%
#1p loss
compareExpression2('ACE2',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('TMPRSS2',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('IFITM3',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=6.535e-01 stat=-4.514e-01
# No Loss: median = -0.38339999999999996, mean = -0.22586750000000003, 95% CI = (-0.5235206506844001, 0.0717856506844001)
# Loss: median = -0.0544, mean = -0.0981, 95% CI = (-0.5329750559949226, 0.3367750559949226)
# No Loss v.s. Loss: t-test independent samples, P_val=1.359e-01 stat=1.514e+00
# No Loss: median = -0.2877, mean = -0.11431250000000001, 95% CI = (-0.5421160293311427, 0.3134910293311427)
# Loss: median = -0.6606, mean = -0.6777933333333332, 95% CI = (-1.0014260729625806, -0.354160593704086)
# No Loss v.s. Loss: t-test independent samples, P_val=3.354e-03 stat=3.072e+00
# No Loss: median = 0.35655, mean = 0.35502500000000003, 95% CI = (0.09270163392963071, 0.6173483660703694)
# Loss: median = -0.5002, mean = -0.5078866666666666, 95% CI = (-1.0765687620785853, 0.06079542874525212)

# %%
#11q loss
compareExpression2('ACE2',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('TMPRSS2',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('IFITM3',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=3.783e-01 stat=8.884e-01
# No Loss: median = -0.11435000000000001, mean = -0.08165, 95% CI = (-0.43637476044205487, 0.27307476044205486)
# Loss: median = -0.2809, mean = -0.30444444444444446, 95% CI = (-0.6438386486835208, 0.034949759794631885)
# No Loss v.s. Loss: t-test independent samples, P_val=5.415e-01 stat=6.145e-01
# No Loss: median = -0.18155, mean = -0.16622142857142858, 95% CI = (-0.5446258987159323, 0.21218304157307505)
# Loss: median = -0.5647, mean = -0.3735259259259259, 95% CI = (-0.9208384726430494, 0.1737866207911976)
# No Loss v.s. Loss: t-test independent samples, P_val=6.548e-01 stat=-4.497e-01
# No Loss: median = 0.2696, mean = 0.05984285714285715, 95% CI = (-0.3603080156511135, 0.47999372993682776)
# Loss: median = 0.2968, mean = 0.18174444444444446, 95% CI = (-0.1390199427793021, 0.502508831668191)

# %%
#17q gain
compareExpression2('ACE2',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('TMPRSS2',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('IFITM3',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
# Out:
# No Gain v.s. Gain: t-test independent samples, P_val=1.335e-01 stat=1.524e+00
# No Gain: median = -0.0383, mean = -0.012668965517241393, 95% CI = (-0.38691561728201473, 0.36157768624753195)
# Gain: median = -0.3045, mean = -0.38995384615384615, 95% CI = (-0.6870812778251918, -0.09282641448250056)
# No Gain v.s. Gain: t-test independent samples, P_val=1.454e-01 stat=1.478e+00
# No Gain: median = -0.2257, mean = -0.03592068965517243, 95% CI = (-0.5558529887426615, 0.48401160943231664)
# Gain: median = -0.55465, mean = -0.5268346153846154, 95% CI = (-0.8960466831511342, -0.15762254761809658)
# No Gain v.s. Gain: t-test independent samples, P_val=7.785e-01 stat=2.827e-01
# No Gain: median = 0.3098, mean = 0.15600689655172414, 95% CI = (-0.2656767627452111, 0.5776905558486594)
# Gain: median = 0.22565000000000002, mean = 0.07917307692307694, 95% CI = (-0.22909534695608808, 0.387441500802242)

# %%
#All three SCAs
compareExpression2('ACE2',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('TMPRSS2',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('IFITM3',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No SCA v.s. SCA: t-test independent samples, P_val=2.892e-02 stat=2.246e+00
# No SCA: median = 0.4546, mean = 0.3220083333333333, 95% CI = (-0.1973672744023483, 0.8413839410690149)
# SCA: median = -0.2809, mean = -0.3341930232558139, 95% CI = (-0.5998797953727767, -0.06850625113885112)
# No SCA v.s. SCA: t-test independent samples, P_val=1.641e-01 stat=1.411e+00
# No SCA: median = 0.057700000000000015, mean = 0.17580833333333332, 95% CI = (-0.43060408171209874, 0.7822207483787654)
# SCA: median = -0.5446, mean = -0.3918395348837209, 95% CI = (-0.7717412729129018, -0.01193779685454005)
# No SCA v.s. SCA: t-test independent samples, P_val=1.278e-01 stat=1.547e+00
# No SCA: median = 0.69155, mean = 0.5086833333333333, 95% CI = (-0.0752261832363158, 1.0925928499029824)
# SCA: median = 0.1545, mean = 0.011127906976744194, 95% CI = (-0.27949709729331695, 0.30175291124680537)

# %% [markdown]
# # TP53/PTPN6/NTRK1 Pathway Analysis

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]
compareExpression2('ACE2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('TMPRSS2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('IFITM3',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-35b2a97485b5> in <module>
#       2 activated_samples = []
#       3
# ----> 4 for sample in z_scores.iloc[:,2:].columns:
#       5     tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
#       6     ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
#
# NameError: name 'z_scores' is not defined

# %%
#TP53
geneScatter('ACE2','TP53')
geneScatter('TMPRSS2','TP53')
geneScatter('IFITM3','TP53')
# Out:
# Pearson correlation coefficient = 0.06222169272403578
# p-value = 0.32814889698946664
# Pearson correlation coefficient = -0.07121242951504084
# p-value = 0.2629350610740419
# Pearson correlation coefficient = -0.023617911139754554
# p-value = 0.7107411755543497

# %%
#PTPN6
geneScatter('ACE2','PTPN6')
geneScatter('TMPRSS2','PTPN6')
geneScatter('IFITM3','PTPN6')
# Out:
# Pearson correlation coefficient = -0.09571036288129589
# p-value = 0.13203010816488836
# Pearson correlation coefficient = 0.032494187131420084
# p-value = 0.6098382191174482
# Pearson correlation coefficient = 0.5341764714398393
# p-value = 8.998083884015434e-20

# %%
#NTRK1
geneScatter('ACE2','NTRK1')
geneScatter('TMPRSS2','NTRK1')
geneScatter('IFITM3','NTRK1')
# Out:
# Pearson correlation coefficient = -0.06783224734274702
# p-value = 0.2863253240949473
# Pearson correlation coefficient = -0.05223861850194082
# p-value = 0.41180330373183166
# Pearson correlation coefficient = 0.18806301640740308
# p-value = 0.002889258146840377

# %% [markdown]
# # Diagnosis Age Analysis

# %%
Age_groups = stratifyNumericalPatientData('Diagnosis Age (days)', 540) #540 days ~ 18 months
compareExpression2('ACE2', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('TMPRSS2', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('IFITM3', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
# Out:
# <18mo v.s. >=18mo: t-test independent samples, P_val=7.624e-01 stat=3.026e-01
# <18mo: median = 0.0338, mean = 0.0510516129032258, 95% CI = (-0.320918657264738, 0.4230218830711896)
# >=18mo: median = -0.0948, mean = -0.007260550458715595, 95% CI = (-0.1395192536872913, 0.1249981527698601)
# <18mo v.s. >=18mo: t-test independent samples, P_val=9.711e-01 stat=-3.631e-02
# <18mo: median = -0.1681, mean = -0.006125806451612923, 95% CI = (-0.3167885493748414, 0.30453693647161556)
# >=18mo: median = -0.0528, mean = 0.0008720183486238336, 95% CI = (-0.13448858122311505, 0.1362326179203627)
# <18mo v.s. >=18mo: t-test independent samples, P_val=2.787e-01 stat=-1.086e+00
# <18mo: median = -0.2012, mean = -0.18273548387096775, 95% CI = (-0.4737187988677162, 0.10824783112578065)
# >=18mo: median = 0.14855000000000002, mean = 0.0259894495412844, 95% CI = (-0.10987616309170142, 0.16185506217427023)

# %% [markdown]
# # Tumor Sample Histology Analysis

# %%
histology_groups = stratifyCategoricalPatientData('Tumor Sample Histology','Unfavorable','Favorable')
compareExpression2('ACE2',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('TMPRSS2',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('IFITM3',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
# Out:
# Unfavorable v.s. Favorable: t-test independent samples, P_val=8.554e-01 stat=-1.824e-01
# Unfavorable: median = -0.0694, mean = 0.01521311475409836, 95% CI = (-0.12870586239576456, 0.1591320919039613)
# Favorable: median = 0.0338, mean = 0.0483108108108108, 95% CI = (-0.2969176394280931, 0.3935392610497147)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=4.669e-01 stat=-7.288e-01
# Unfavorable: median = -0.065, mean = -0.05091803278688525, 95% CI = (-0.19304820268070316, 0.09121213710693266)
# Favorable: median = -0.0532, mean = 0.07735675675675677, 95% CI = (-0.2296836694746581, 0.3843971829881716)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=7.717e-01 stat=2.905e-01
# Unfavorable: median = 0.055999999999999994, mean = -0.0281169398907104, 95% CI = (-0.18387950429292907, 0.12764562451150827)
# Favorable: median = -0.1851, mean = -0.0818918918918919, 95% CI = (-0.31939920853600945, 0.15561542475222567)

# %% [markdown]
# # Neoplasm Histologic Grade Analysis

# %%
histologic_grade_groups = stratifyCategoricalSampleData('Neoplasm Histologic Grade','Undifferentiated or Poorly Differentiated','Differentiating')
compareExpression2('ACE2',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('TMPRSS2',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('IFITM3',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
# Out:
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=4.483e-01 stat=-7.599e-01
# Undifferentiated: median = -0.09695, mean = -0.0022547058823529425, 95% CI = (-0.15315671063440423, 0.14864729886969835)
# Differentiating: median = 0.2354, mean = 0.2176461538461538, 95% CI = (-0.3423524019965224, 0.77764470968883)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=4.250e-02 stat=-2.043e+00
# Undifferentiated: median = -0.05555, mean = -0.05491294117647062, 95% CI = (-0.20017463413726339, 0.09034875178432213)
# Differentiating: median = 0.8022, mean = 0.5139461538461538, 95% CI = (-0.021684033471004005, 1.0495763411633117)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=5.723e-01 stat=-5.658e-01
# Undifferentiated: median = -0.00935, mean = -0.07473470588235294, 95% CI = (-0.23168615031316764, 0.08221673854846177)
# ...

# %% [markdown]
# # Repeat analyses above for only samples without MYCN amplification

# %%
#Stratify samples based on MYCN amplification
MYCN_groups = stratifyCategoricalSampleData('MYCN', 'Not Amplified', 'Amplified')

#Find z-scores for MYCN nonamplified samples
nonamplified_MYCN_columns = ['Hugo_Symbol','Entrez_Gene_Id'] + list(set(MYCN_groups[0]).intersection(z_scores.columns))
nonamplified_MYCN_z_scores = z_scores[nonamplified_MYCN_columns]

# %% [markdown]
# ### EFS Analysis

# %%
#ACE2
ACE2_groups = stratifyDataOnGeneExpression('ACE2',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(ACE2_groups, 'EFS in MYCN nonamplified samples stratified by ACE2 expression', ['Low ACE2','High ACE2'], 't-test_ind')
kaplanmeierEFS(ACE2_groups,'Low ACE2','High ACE2')
# Out:
# Low ACE2 v.s. High ACE2: t-test independent samples, P_val=4.784e-02 stat=2.003e+00
# Low ACE2: median = 1843.0, mean = 1960.542372881356, 95% CI = (1541.4555869065111, 2379.629158856201)
# High ACE2: median = 632.0, mean = 1366.5555555555557, 95% CI = (991.3838659376314, 1741.7272451734798)

# %%
#TMPRSS2
TMPRSS2_groups = stratifyDataOnGeneExpression('TMPRSS2',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(TMPRSS2_groups, 'EFS in MYCN nonamplified samples stratified by TMPRSS2 expression', ['Low TMPRSS2','High TMPRSS2'], 't-test_ind')
kaplanmeierEFS(TMPRSS2_groups,'Low TMPRSS2','High TMPRSS2')
# Out:
# Low TMPRSS2 v.s. High TMPRSS2: t-test independent samples, P_val=6.058e-01 stat=5.178e-01
# Low TMPRSS2: median = 1021.5, mean = 1842.5961538461538, 95% CI = (1389.8075183318301, 2295.3847893604775)
# High TMPRSS2: median = 800.0, mean = 1671.2954545454545, 95% CI = (1212.5175015349746, 2130.0734075559344)

# %%
#IFITM3
IFITM3_groups = stratifyDataOnGeneExpression('IFITM3',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(IFITM3_groups, 'EFS in MYCN nonamplified samples stratified by IFITM3 expression', ['Low IFITM3','High IFITM3'], 't-test_ind')
kaplanmeierEFS(IFITM3_groups,'Low IFITM3','High IFITM3')
# Out:
# Low IFITM3 v.s. High IFITM3: t-test independent samples, P_val=1.827e-01 stat=1.342e+00
# Low IFITM3: median = 798.0, mean = 1680.2820512820513, 95% CI = (1190.6803038766993, 2169.883798687403)
# High IFITM3: median = 708.5, mean = 1300.3666666666666, 95% CI = (985.6638186921064, 1615.0695146412268)

# %% [markdown]
# ### MYCN Analysis

# %%
geneScatter('ACE2','MYCN',z_scores=nonamplified_MYCN_z_scores)
geneScatter('TMPRSS2','MYCN',z_scores=nonamplified_MYCN_z_scores)
geneScatter('IFITM3','MYCN',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.19543594350182183
# p-value = 0.009545041457289107
# Pearson correlation coefficient = -0.2187370726046483
# p-value = 0.0036353445026745057
# Pearson correlation coefficient = -0.23726613351114628
# p-value = 0.0015695233048638063

# %% [markdown]
# ### SCA Analysis

# %%
#1p loss
ch1p_non_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch1p_non_loss_samples)))
ch1p_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch1p_loss_samples)))
compareExpression2('ACE2',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('TMPRSS2',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('IFITM3',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=9.875e-01 stat=1.577e-02
# No Loss: median = -0.44284999999999997, mean = -0.32039375, 95% CI = (-0.6522723070614966, 0.011484807061496682)
# Loss: median = -0.053799999999999994, mean = -0.32715, 95% CI = (-1.1234359249381787, 0.46913592493817874)
# No Loss v.s. Loss: t-test independent samples, P_val=6.780e-01 stat=4.186e-01
# No Loss: median = -0.36855, mean = -0.2626625, 95% CI = (-0.7456920353422392, 0.22036703534223911)
# Loss: median = -0.42305, mean = -0.5071166666666667, 95% CI = (-0.9838486691599175, -0.030384664173415732)
# No Loss v.s. Loss: t-test independent samples, P_val=4.750e-01 stat=7.219e-01
# No Loss: median = 0.3164, mean = 0.35993437500000003, 95% CI = (0.07310638751943022, 0.6467623624805698)
# Loss: median = 0.3457, mean = 0.08651666666666669, 95% CI = (-0.7014516338987946, 0.874484967232128)

# %%
#11q loss
ch11q_non_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch11q_non_loss_samples)))
ch11q_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch11q_loss_samples)))
compareExpression2('ACE2',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('TMPRSS2',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('IFITM3',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=9.936e-01 stat=-8.099e-03
# No Loss: median = -0.5494, mean = -0.3232153846153846, 95% CI = (-0.8767081869594222, 0.230277417728653)
# Loss: median = -0.3281, mean = -0.320548, 95% CI = (-0.6868214680662612, 0.045725468066261155)
# No Loss v.s. Loss: t-test independent samples, P_val=8.514e-01 stat=1.886e-01
# No Loss: median = -0.1374, mean = -0.24545384615384616, 95% CI = (-0.723232572029191, 0.2323248797214987)
# Loss: median = -0.5647, mean = -0.33027999999999996, 95% CI = (-0.9127777054549246, 0.2522177054549248)
# No Loss v.s. Loss: t-test independent samples, P_val=8.675e-01 stat=1.681e-01
# No Loss: median = 0.32299999999999995, mean = 0.3491692307692308, 95% CI = (-0.20839415575099096, 0.9067326172894525)
# Loss: median = 0.3198, mean = 0.29991200000000007, 95% CI = (0.002384866965289667, 0.5974391330347104)

# %%
#17q gain
ch17q_non_gain_samples = list(set(MYCN_groups[0]).intersection(set(ch17q_non_gain_samples)))
ch17q_gain_samples = list(set(MYCN_groups[0]).intersection(set(ch17q_gain_samples)))
compareExpression2('ACE2',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('TMPRSS2',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('IFITM3',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
# Out:
# No Gain v.s. Gain: t-test independent samples, P_val=2.075e-01 stat=1.284e+00
# No Gain: median = -0.2675, mean = -0.12534210526315792, 95% CI = (-0.6087480695037695, 0.35806385897745363)
# Gain: median = -0.447, mean = -0.517578947368421, 95% CI = (-0.8711392417119079, -0.16401865302493418)
# No Gain v.s. Gain: t-test independent samples, P_val=7.226e-02 stat=1.852e+00
# No Gain: median = -0.1374, mean = 0.07643684210526312, 95% CI = (-0.6222964887808141, 0.7751701729913404)
# Gain: median = -0.602, mean = -0.6789578947368422, 95% CI = (-1.0675030324705825, -0.2904127570031018)
# No Gain v.s. Gain: t-test independent samples, P_val=3.925e-01 stat=8.655e-01
# No Gain: median = 0.3901, mean = 0.43593157894736845, 95% CI = (-0.03209092254584084, 0.9039540804405777)
# Gain: median = 0.2968, mean = 0.19759473684210527, 95% CI = (-0.07116637742551979, 0.4663558511097303)

# %%
#All three SCAs
non_sca_samples = list(set(MYCN_groups[0]).intersection(set(non_sca_samples)))
sca_samples = list(set(MYCN_groups[0]).intersection(set(sca_samples)))
compareExpression2('ACE2',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('TMPRSS2',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('IFITM3',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No SCA v.s. SCA: t-test independent samples, P_val=8.076e-02 stat=1.797e+00
# No SCA: median = 0.21185, mean = 0.199325, 95% CI = (-0.4033701303440034, 0.8020201303440033)
# SCA: median = -0.44284999999999997, mean = -0.46033666666666667, 95% CI = (-0.794908115159527, -0.12576521817380631)
# No SCA v.s. SCA: t-test independent samples, P_val=4.191e-01 stat=8.174e-01
# No SCA: median = -0.20274999999999999, mean = 0.03352500000000001, 95% CI = (-0.47739896603096776, 0.5444489660309678)
# SCA: median = -0.55465, mean = -0.39053666666666664, 95% CI = (-0.893913392130716, 0.11284005879738268)
# No SCA v.s. SCA: t-test independent samples, P_val=5.551e-01 stat=5.957e-01
# No SCA: median = 0.46685, mean = 0.47645000000000004, 95% CI = (-0.35589486368547196, 1.308794863685472)
# SCA: median = 0.32139999999999996, mean = 0.27418000000000003, 95% CI = (0.0074401309431980645, 0.540919869056802)

# %% [markdown]
# ### TP53/PTPN6/NTRK1 Pathway Analysis

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

activated_samples = list(set(MYCN_groups[0]).intersection(set(activated_samples)))
nonactivated_samples = list(set(MYCN_groups[0]).intersection(set(nonactivated_samples)))

data = [activated_samples,nonactivated_samples]
compareExpression2('ACE2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('TMPRSS2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('IFITM3',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=6.795e-01 stat=4.138e-01
# Activated: median = 0.1974, mean = 0.028663157894736842, 95% CI = (-0.2422597145303858, 0.2995860303198595)
# Not activated: median = -0.1639, mean = -0.07120128205128204, 95% CI = (-0.2326589347255517, 0.09025637062298764)
# Activated v.s. Not activated: t-test independent samples, P_val=2.417e-01 stat=1.175e+00
# Activated: median = 0.1449, mean = 0.21911052631578948, 95% CI = (-0.2441292448436942, 0.6823502974752731)
# Not activated: median = -0.1063, mean = -0.06444807692307691, 95% CI = (-0.21964643152013574, 0.09075027767398192)
# Activated v.s. Not activated: t-test independent samples, P_val=1.005e-03 stat=-3.346e+00
# Activated: median = -0.4478, mean = -0.4423315789473683, 95% CI = (-0.6785912989052535, -0.20607185898948313)
# Not activated: median = 0.32139999999999996, mean = 0.2512929487179487, 95% CI = (0.11268123221521006, 0.38990466522068734)

# %%
#TP53
geneScatter('ACE2','TP53',z_scores=nonamplified_MYCN_z_scores)
geneScatter('TMPRSS2','TP53',z_scores=nonamplified_MYCN_z_scores)
geneScatter('IFITM3','TP53',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.010989506853144905
# p-value = 0.8852319714095873
# Pearson correlation coefficient = -0.023918721963807357
# p-value = 0.7533749601228814
# Pearson correlation coefficient = 0.2484103983582145
# p-value = 0.000917337470442439

# %%
#PTPN6
geneScatter('ACE2','PTPN6',z_scores=nonamplified_MYCN_z_scores)
geneScatter('TMPRSS2','PTPN6',z_scores=nonamplified_MYCN_z_scores)
geneScatter('IFITM3','PTPN6',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.07827201926629156
# p-value = 0.3031970695905255
# Pearson correlation coefficient = -0.021987835047656404
# p-value = 0.7727174996994843
# Pearson correlation coefficient = 0.4337598757997754
# p-value = 2.016890611993847e-09

# %%
#NTRK1
geneScatter('ACE2','NTRK1',z_scores=nonamplified_MYCN_z_scores)
geneScatter('TMPRSS2','NTRK1',z_scores=nonamplified_MYCN_z_scores)
geneScatter('IFITM3','NTRK1',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.0010509217964856689
# p-value = 0.988987339446833
# Pearson correlation coefficient = -0.046209864885723234
# p-value = 0.5436898405936511
# Pearson correlation coefficient = -0.06237029773021042
# p-value = 0.41223475555966543

# %% [markdown]
# ### Diagnosis Age Analysis

# %%
Age_groups = stratifyNumericalPatientData('Diagnosis Age (days)', 540) #540 days ~ 18 months
Age_groups[0] = list(set(MYCN_groups[0]).intersection(set(Age_groups[0])))
Age_groups[1] = list(set(MYCN_groups[0]).intersection(set(Age_groups[1])))
compareExpression2('ACE2', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('TMPRSS2', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('IFITM3', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
# Out:
# <18mo v.s. >=18mo: t-test independent samples, P_val=3.417e-01 stat=9.534e-01
# <18mo: median = 0.1322, mean = 0.09989310344827584, 95% CI = (-0.2889383690226239, 0.48872457591917556)
# >=18mo: median = -0.15935, mean = -0.09218972602739726, 95% CI = (-0.25039980007310986, 0.06602034801831531)
# <18mo v.s. >=18mo: t-test independent samples, P_val=7.997e-01 stat=2.542e-01
# <18mo: median = -0.0532, mean = 0.009327586206896535, 95% CI = (-0.3223229368609395, 0.3409781092747326)
# >=18mo: median = -0.08725, mean = -0.04220068493150685, 95% CI = (-0.20650071221899538, 0.12209934235598166)
# <18mo v.s. >=18mo: t-test independent samples, P_val=9.883e-02 stat=-1.659e+00
# <18mo: median = -0.1851, mean = -0.06983793103448274, 95% CI = (-0.3341495204601227, 0.19447365839115724)
# >=18mo: median = 0.30575, mean = 0.22481301369863013, 95% CI = (0.07898901770837716, 0.37063700968888313)

# %% [markdown]
# ### Tumor Sample Histology Analysis

# %%
histology_groups = stratifyCategoricalPatientData('Tumor Sample Histology','Unfavorable','Favorable')
histology_groups[0] = list(set(MYCN_groups[0]).intersection(set(histology_groups[0])))
histology_groups[1] = list(set(MYCN_groups[0]).intersection(set(histology_groups[1])))
compareExpression2('ACE2',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('TMPRSS2',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('IFITM3',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
# Out:
# Unfavorable v.s. Favorable: t-test independent samples, P_val=6.091e-01 stat=-5.124e-01
# Unfavorable: median = -0.08005000000000001, mean = -0.047310655737704904, 95% CI = (-0.2194795185840579, 0.12485820710864809)
# Favorable: median = 0.0338, mean = 0.0483108108108108, 95% CI = (-0.2969176394280931, 0.3935392610497147)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=4.633e-01 stat=-7.352e-01
# Unfavorable: median = -0.07535, mean = -0.05744098360655738, 95% CI = (-0.23205449315540366, 0.11717252594228889)
# Favorable: median = -0.0532, mean = 0.07735675675675677, 95% CI = (-0.2296836694746581, 0.3843971829881716)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=4.316e-02 stat=2.039e+00
# Unfavorable: median = 0.32139999999999996, mean = 0.2517360655737705, 95% CI = (0.09057709648156415, 0.4128950346659768)
# Favorable: median = -0.1851, mean = -0.0818918918918919, 95% CI = (-0.31939920853600945, 0.15561542475222567)

# %% [markdown]
# # Neoplasm Histologic Grade Analysis

# %%
histologic_grade_groups = stratifyCategoricalSampleData('Neoplasm Histologic Grade','Undifferentiated or Poorly Differentiated','Differentiating')
histologic_grade_groups[0] = list(set(MYCN_groups[0]).intersection(set(histologic_grade_groups[0])))
histologic_grade_groups[1] = list(set(MYCN_groups[0]).intersection(set(histologic_grade_groups[1])))
compareExpression2('ACE2',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('TMPRSS2',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('IFITM3',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
# Out:
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=3.629e-01 stat=-9.131e-01
# Undifferentiated: median = -0.08065, mean = -0.0468614035087719, 95% CI = (-0.22769683881547742, 0.1339740317979336)
# Differentiating: median = 0.2354, mean = 0.2176461538461538, 95% CI = (-0.3423524019965224, 0.77764470968883)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=4.577e-02 stat=-2.018e+00
# Undifferentiated: median = -0.05935, mean = -0.05552192982456142, 95% CI = (-0.23208718735533382, 0.12104332770621098)
# Differentiating: median = 0.8022, mean = 0.5139461538461538, 95% CI = (-0.021684033471004005, 1.0495763411633117)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=7.290e-01 stat=3.472e-01
# Undifferentiated: median = 0.23709999999999998, mean = 0.1799052631578947, 95% CI = (0.02282291723776228, 0.33698760907802716)
# ...
