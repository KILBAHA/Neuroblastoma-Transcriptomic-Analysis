# %%
library(metaMA)

# %%
target <- read.table(file = '../nbl_target_2018_pub/data_expression_median.txt',sep='\t',header=TRUE)

# %%
target
# Out:
#       Hugo_Symbol Entrez_Gene_Id TARGET.30.PAAPFA.01 TARGET.30.PACLJN.01
# 1     A1BG                1       6.967810           7.142617
# 2     A1BG-AS        503538       6.852955           7.250045
# 3     A1CF            29974       4.244608           4.006119
# 4     A2LD1           87769       6.457230           6.929296
# 5     A2M                 2      10.373367           9.955901
# 6     A2ML1          144568       4.238173           4.440602
# 7     A4GALT          53947       6.843422           7.061390
# 8     A4GNT           51146       5.122570           5.219511
# 9     AAA1        100329167       4.043651           4.310269
# 10    AAAS             8086       8.450991           8.560049
# 11    AACS            65985       7.929435           7.249233
# 12    AACSP1         729522       8.019190           7.708109
# 13    AADAC              13       2.803398           3.072477
# 14    AADACL2        344752       3.550680           3.527503
# ...

# %%
geo <- read.csv('../GSE49711/GSE49711_SEQC_NB_MAV_G_log2.20121127.csv',header=TRUE)

# %%
geo
# Out:
#       X.Gene    X.NCBI.GeneId
# 1     ALB       213
# 2     CD24L4.1  938;100133941
# 3     RPS11     6205
# 4     RPS18     6222
# 5     C5orf13   9315
# 6     CCT2      10576
# 7     COL1A1    1277
# 8     DDX1      1653
# 9     EEF1A1    1915
# 10    FLT3LG_   2323;23521;26819;26818;26817;26816
# 11    H3F3B     3021
# 12    IAH1      285148
# 13    IGHV_     28453;28440;28435;28425;28382
# 14    IGK_      3514;28299;50802
# 15    NPY       4852
# 16    ODC1      4953
# 17    ORM1      5004
# 18    RGS5      8490
# 19    RN7SL2    378706
# 20    RPL13     6137
# 21    RPL18A    6142
# 22    RPL23     9349
# 23    RPL26     6154
# 24    RPL27     6155
# 25    RPL29     6159
# 26    RPL31     6160
# 27    RPL37A    6168
# 28    RPS15A    6210
# 29    RPS17     6218
# 30    RPS2      6187
# ⋮     ⋮         ⋮
# 60749 zoysteeby
# 60750 zoyswerby
# 60751 zoytawbu
# 60752 zoytu
# 60753 zubeybo
# 60754 zudee
# 60755 zufobu
# 60756 zukleybu
# 60757 zurey
# 60758 zureyby
# 60759 zurobo
# ...
