# %%
from ipynb.fs.full.GEO_Analysis_Functions import *
# Out:
# /Users/brandonbergs/anaconda2/envs/v3_8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %% [markdown]
# # EFS Analysis

# %%
groups = stratifyDataOnGeneExpression('TMPRSS2',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by TMPRSS2 Expression', ['Low TMPRSS2','High TMPRSS2'], 't-test_ind')
kaplanmeierEFS(groups, 'Low TMPRSS2', 'High TMPRSS2')
# Out:
# Low TMPRSS2 v.s. High TMPRSS2: t-test independent samples, P_val=2.840e-01 stat=1.078e+00
# Low TMPRSS2: median = 2026.5, mean = 2254.469696969697, 95% CI = (1882.457781729161, 2626.481612210233)
# High TMPRSS2: median = 1813.0, mean = 1898.5862068965516, 95% CI = (1412.9918979629886, 2384.1805158301145)

# %%
groups = stratifyDataOnGeneExpression('IFITM2',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by IFITM2 Expression', ['Low IFITM2','High IFITM2'], 't-test_ind')
kaplanmeierEFS(groups, 'Low IFITM2', 'High IFITM2')
# Out:
# Low IFITM2 v.s. High IFITM2: t-test independent samples, P_val=6.816e-01 stat=-4.107e-01
# Low IFITM2: median = 1403.5, mean = 1693.3181818181818, 95% CI = (1465.4474419113108, 1921.1889217250528)
# High IFITM2: median = 1419.5, mean = 1759.9133333333334, 95% CI = (1538.6285362074236, 1981.1981304592432)

# %%
groups = stratifyDataOnGeneExpression('CXCL10',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by CXCL10 Expression', ['Low CXCL10','High CXCL10'], 't-test_ind')
kaplanmeierEFS(groups, 'Low CXCL10', 'High CXCL10')
# Out:
# Low CXCL10 v.s. High CXCL10: t-test independent samples, P_val=4.729e-01 stat=-7.188e-01
# Low CXCL10: median = 1330.0, mean = 1645.3636363636363, 95% CI = (1415.8059148216032, 1874.9213579056693)
# High CXCL10: median = 1560.0, mean = 1764.5448275862068, 95% CI = (1534.5443761718564, 1994.5452790005572)

# %%
groups = stratifyDataOnGeneExpression('CXCL11',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by CXCL11 Expression', ['Low CXCL11','High CXCL11'], 't-test_ind')
kaplanmeierEFS(groups, 'Low CXCL11', 'High CXCL11')
# Out:
# Low CXCL11 v.s. High CXCL11: t-test independent samples, P_val=2.176e-02 stat=2.307e+00
# Low CXCL11: median = 1810.0, mean = 1946.125786163522, 95% CI = (1728.1091939627527, 2164.1423783642913)
# High CXCL11: median = 1072.5, mean = 1569.6742424242425, 95% CI = (1336.7697135605993, 1802.5787712878857)

# %%
groups = stratifyDataOnGeneExpression('AGTR1',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by AGTR1 Expression', ['Low AGTR1','High AGTR1'], 't-test_ind')
kaplanmeierEFS(groups, 'Low AGTR1', 'High AGTR1')
# Out:
# Low AGTR1 v.s. High AGTR1: t-test independent samples, P_val=9.837e-03 stat=-2.597e+00
# Low AGTR1: median = 1223.0, mean = 1619.2278481012659, 95% CI = (1403.4844789911403, 1834.9712172113914)
# High AGTR1: median = 1907.0, mean = 2044.8703703703704, 95% CI = (1807.4742783977717, 2282.266462342969)

# %%
groups = stratifyDataOnGeneExpression('BSG',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by BSG Expression', ['Low BSG','High BSG'], 't-test_ind')
kaplanmeierEFS(groups, 'Low BSG', 'High BSG')
# Out:
# Low BSG v.s. High BSG: t-test independent samples, P_val=7.864e-11 stat=6.736e+00
# Low BSG: median = 2365.0, mean = 2343.88622754491, 95% CI = (2130.9907711414307, 2556.7816839483894)
# High BSG: median = 720.0, mean = 1305.0, 95% CI = (1092.1160977303875, 1517.8839022696125)

# %%
groups = stratifyDataOnGeneExpression('DPP4',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by DPP4 Expression', ['Low DPP4','High DPP4'], 't-test_ind')
kaplanmeierEFS(groups, 'Low DPP4', 'High DPP4')
# Out:
# Low DPP4 v.s. High DPP4: t-test independent samples, P_val=1.171e-04 stat=-3.905e+00
# Low DPP4: median = 649.5, mean = 1404.3507462686566, 95% CI = (1162.6580455415385, 1646.0434469957747)
# High DPP4: median = 1818.0, mean = 2066.8980891719743, 95% CI = (1839.290436246922, 2294.505742097027)

# %%
groups = stratifyDataOnGeneExpression('PPIA',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by PPIA Expression', ['Low PPIA','High PPIA'], 't-test_ind')
kaplanmeierEFS(groups, 'Low PPIA', 'High PPIA')
# Out:
# Low PPIA v.s. High PPIA: t-test independent samples, P_val=2.712e-13 stat=7.655e+00
# Low PPIA: median = 2360.0, mean = 2404.8563218390805, 95% CI = (2192.669844370736, 2617.042799307425)
# High PPIA: median = 635.0, mean = 1184.420634920635, 95% CI = (963.137340819148, 1405.7039290221219)

# %%
groups = stratifyDataOnGeneExpression('PPIB',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by PPIB Expression', ['Low PPIB','High PPIB'], 't-test_ind')
kaplanmeierEFS(groups, 'Low PPIB', 'High PPIB')
# Out:
# Low PPIB v.s. High PPIB: t-test independent samples, P_val=1.744e-10 stat=6.612e+00
# Low PPIB: median = 2283.0, mean = 2375.539393939394, 95% CI = (2136.655171217892, 2614.4236166608957)
# High PPIB: median = 729.0, mean = 1266.3455882352941, 95% CI = (1049.2065530083435, 1483.4846234622448)

# %% [markdown]
# # MYCN Amplification Analysis

# %%
MYCN_groups = stratifyClinicalData('MYCN Amplification',[0,1])
compareExpression('TMPRSS2',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('IFITM2',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('CXCL10',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('CXCL11',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('AGTR1',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('BSG',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('DPP4',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('PPIA',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
compareExpression('PPIB',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.507e-01 stat=1.443e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.507e-01 stat=1.443e+00
# Not Amplified: median = -0.3236401333959047, mean = -0.002235991774206122
# Amplified: median = -0.48617092965430636, mean = -0.36034587033045995
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.387e-06 stat=4.700e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.387e-06 stat=4.700e+00
# Not Amplified: median = 0.018485039701271043, mean = 0.09976845718959194
# Amplified: median = -0.4823168799185216, mean = -0.43404864990347924
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.204e-06 stat=4.917e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.204e-06 stat=4.917e+00
# Not Amplified: median = -0.018913705099311683, mean = 0.0960479314042122
# Amplified: median = -0.4500855377953216, mean = -0.4754144660837418
# ...

# %%
geneScatter('TMPRSS2','MYCN')
geneScatter('IFITM2','MYCN')
geneScatter('CXCL10','MYCN')
geneScatter('CXCL11','MYCN')
geneScatter('AGTR1','MYCN')
geneScatter('BSG','MYCN')
geneScatter('DPP4','MYCN')
geneScatter('PPIA','MYCN')
geneScatter('PPIB','MYCN')
# Out:
# Pearson correlation coefficient = -0.140206014406575
# p-value = 0.06121432967733842
# Pearson correlation coefficient = -0.30756446592497394
# p-value = 2.2646049349311384e-12
# Pearson correlation coefficient = -0.2694612841011679
# p-value = 1.2931577162542614e-09
# Pearson correlation coefficient = -0.08966327680511121
# p-value = 0.06021319950186003
# Pearson correlation coefficient = -0.20494298242781667
# p-value = 4.481424166977579e-06
# Pearson correlation coefficient = 0.3127750384734541
# p-value = 9.178616232671396e-13
# Pearson correlation coefficient = -0.4755665797183393
# p-value = 1.814799724003519e-29
# Pearson correlation coefficient = 0.39669004567690747
# p-value = 3.234664687953446e-20
# Pearson correlation coefficient = 0.3102780211175042
# p-value = 1.4180806088256737e-12

# %% [markdown]
# # Compare expression between INSS Stages

# %%
INSS_groups = stratifyClinicalData('INSS Stage',['1', '2', '3', '4', '4S'])
compareExpression('TMPRSS2',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=5.367e-01 stat=-6.203e-01
# 2 v.s. 3: t-test independent samples, P_val=2.548e-01 stat=1.150e+00
# 3 v.s. 4: t-test independent samples, P_val=2.553e-01 stat=-1.148e+00
# 4 v.s. 4S: t-test independent samples, P_val=1.902e-04 stat=-3.944e+00
# 1 v.s. 3: t-test independent samples, P_val=4.642e-01 stat=7.361e-01
# 2 v.s. 4: t-test independent samples, P_val=6.032e-01 stat=-5.218e-01
# 3 v.s. 4S: t-test independent samples, P_val=3.778e-04 stat=-3.851e+00
# 1 v.s. 4: t-test independent samples, P_val=2.953e-01 stat=-1.052e+00
# 2 v.s. 4S: t-test independent samples, P_val=4.369e-05 stat=-4.409e+00
# 1 v.s. 4S: t-test independent samples, P_val=8.879e-07 stat=-5.372e+00
# 1 v.s. 2: t-test independent samples, P_val=5.367e-01 stat=-6.203e-01
# 2 v.s. 3: t-test independent samples, P_val=2.548e-01 stat=1.150e+00
# 3 v.s. 4: t-test independent samples, P_val=2.553e-01 stat=-1.148e+00
# ...

# %%
compareExpression('IFITM2',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=9.075e-01 stat=1.163e-01
# 2 v.s. 3: t-test independent samples, P_val=1.214e-01 stat=1.559e+00
# 3 v.s. 4: t-test independent samples, P_val=9.262e-01 stat=-9.274e-02
# 4 v.s. 4S: t-test independent samples, P_val=1.405e-03 stat=-3.232e+00
# 1 v.s. 3: t-test independent samples, P_val=5.868e-02 stat=1.903e+00
# 2 v.s. 4: t-test independent samples, P_val=1.472e-01 stat=1.454e+00
# 3 v.s. 4S: t-test independent samples, P_val=3.675e-04 stat=-3.672e+00
# 1 v.s. 4: t-test independent samples, P_val=6.215e-02 stat=1.872e+00
# 2 v.s. 4S: t-test independent samples, P_val=1.817e-02 stat=-2.393e+00
# 1 v.s. 4S: t-test independent samples, P_val=1.029e-02 stat=-2.595e+00
# 1 v.s. 2: t-test independent samples, P_val=9.075e-01 stat=1.163e-01
# 2 v.s. 3: t-test independent samples, P_val=1.214e-01 stat=1.559e+00
# 3 v.s. 4: t-test independent samples, P_val=9.262e-01 stat=-9.274e-02
# ...

# %%
compareExpression('CXCL10',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=3.259e-01 stat=-9.848e-01
# 2 v.s. 3: t-test independent samples, P_val=1.633e-01 stat=1.401e+00
# 3 v.s. 4: t-test independent samples, P_val=5.157e-01 stat=-6.510e-01
# 4 v.s. 4S: t-test independent samples, P_val=8.789e-01 stat=1.526e-01
# 1 v.s. 3: t-test independent samples, P_val=4.348e-01 stat=7.827e-01
# 2 v.s. 4: t-test independent samples, P_val=4.073e-01 stat=8.301e-01
# 3 v.s. 4S: t-test independent samples, P_val=6.955e-01 stat=-3.924e-01
# 1 v.s. 4: t-test independent samples, P_val=9.904e-01 stat=-1.205e-02
# 2 v.s. 4S: t-test independent samples, P_val=4.278e-01 stat=7.955e-01
# 1 v.s. 4S: t-test independent samples, P_val=8.658e-01 stat=1.693e-01
# 1 v.s. 2: t-test independent samples, P_val=3.259e-01 stat=-9.848e-01
# 2 v.s. 3: t-test independent samples, P_val=1.633e-01 stat=1.401e+00
# 3 v.s. 4: t-test independent samples, P_val=5.157e-01 stat=-6.510e-01
# ...

# %%
compareExpression('CXCL11',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=6.431e-02 stat=-1.861e+00
# 2 v.s. 3: t-test independent samples, P_val=4.732e-01 stat=7.195e-01
# 3 v.s. 4: t-test independent samples, P_val=7.893e-02 stat=-1.765e+00
# 4 v.s. 4S: t-test independent samples, P_val=3.943e-02 stat=2.073e+00
# 1 v.s. 3: t-test independent samples, P_val=3.568e-01 stat=-9.241e-01
# 2 v.s. 4: t-test independent samples, P_val=2.818e-01 stat=-1.079e+00
# 3 v.s. 4S: t-test independent samples, P_val=6.768e-01 stat=4.182e-01
# 1 v.s. 4: t-test independent samples, P_val=6.071e-04 stat=-3.469e+00
# 2 v.s. 4S: t-test independent samples, P_val=2.842e-01 stat=1.076e+00
# 1 v.s. 4S: t-test independent samples, P_val=7.389e-01 stat=-3.339e-01
# 1 v.s. 2: t-test independent samples, P_val=6.431e-02 stat=-1.861e+00
# 2 v.s. 3: t-test independent samples, P_val=4.732e-01 stat=7.195e-01
# 3 v.s. 4: t-test independent samples, P_val=7.893e-02 stat=-1.765e+00
# ...

# %%
compareExpression('AGTR1',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=1.933e-01 stat=1.305e+00
# 2 v.s. 3: t-test independent samples, P_val=5.885e-01 stat=-5.422e-01
# 3 v.s. 4: t-test independent samples, P_val=4.337e-04 stat=3.568e+00
# 4 v.s. 4S: t-test independent samples, P_val=1.239e-07 stat=-5.459e+00
# 1 v.s. 3: t-test independent samples, P_val=4.528e-01 stat=7.524e-01
# 2 v.s. 4: t-test independent samples, P_val=2.876e-03 stat=3.010e+00
# 3 v.s. 4S: t-test independent samples, P_val=2.484e-02 stat=-2.274e+00
# 1 v.s. 4: t-test independent samples, P_val=5.551e-07 stat=5.118e+00
# 2 v.s. 4S: t-test independent samples, P_val=1.359e-02 stat=-2.502e+00
# 1 v.s. 4S: t-test independent samples, P_val=1.241e-01 stat=-1.545e+00
# 1 v.s. 2: t-test independent samples, P_val=1.933e-01 stat=1.305e+00
# 2 v.s. 3: t-test independent samples, P_val=5.885e-01 stat=-5.422e-01
# 3 v.s. 4: t-test independent samples, P_val=4.337e-04 stat=3.568e+00
# ...

# %%
compareExpression('BSG',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=2.243e-01 stat=1.219e+00
# 2 v.s. 3: t-test independent samples, P_val=3.880e-02 stat=-2.086e+00
# 3 v.s. 4: t-test independent samples, P_val=4.939e-04 stat=-3.532e+00
# 4 v.s. 4S: t-test independent samples, P_val=9.472e-04 stat=3.348e+00
# 1 v.s. 3: t-test independent samples, P_val=2.483e-01 stat=-1.158e+00
# 2 v.s. 4: t-test independent samples, P_val=5.083e-09 stat=-6.049e+00
# 3 v.s. 4S: t-test independent samples, P_val=9.818e-01 stat=-2.288e-02
# 1 v.s. 4: t-test independent samples, P_val=1.180e-08 stat=-5.865e+00
# 2 v.s. 4S: t-test independent samples, P_val=3.361e-02 stat=-2.148e+00
# 1 v.s. 4S: t-test independent samples, P_val=2.411e-01 stat=-1.176e+00
# 1 v.s. 2: t-test independent samples, P_val=2.243e-01 stat=1.219e+00
# 2 v.s. 3: t-test independent samples, P_val=3.880e-02 stat=-2.086e+00
# 3 v.s. 4: t-test independent samples, P_val=4.939e-04 stat=-3.532e+00
# ...

# %%
compareExpression('DPP4',INSS_groups,'INSS Stage',['1', '2', '3', '4', '4S'], 't-test_ind')
# Out:
# 1 v.s. 2: t-test independent samples, P_val=5.378e-01 stat=-6.172e-01
# 2 v.s. 3: t-test independent samples, P_val=5.310e-02 stat=1.951e+00
# 3 v.s. 4: t-test independent samples, P_val=2.756e-02 stat=2.217e+00
# 4 v.s. 4S: t-test independent samples, P_val=4.785e-08 stat=-5.644e+00
# 1 v.s. 3: t-test independent samples, P_val=8.985e-02 stat=1.705e+00
# 2 v.s. 4: t-test independent samples, P_val=7.068e-06 stat=4.585e+00
# 3 v.s. 4S: t-test independent samples, P_val=9.229e-04 stat=-3.402e+00
# 1 v.s. 4: t-test independent samples, P_val=1.456e-06 stat=4.915e+00
# 2 v.s. 4S: t-test independent samples, P_val=5.554e-02 stat=-1.932e+00
# 1 v.s. 4S: t-test independent samples, P_val=6.747e-03 stat=-2.742e+00
# 1 v.s. 2: t-test independent samples, P_val=5.378e-01 stat=-6.172e-01
# 2 v.s. 3: t-test independent samples, P_val=5.310e-02 stat=1.951e+00
# 3 v.s. 4: t-test independent samples, P_val=2.756e-02 stat=2.217e+00
# ...

# %% [markdown]
# # Compare expression between groups with and without activated TP53/PTPN6/NTRK1 pathway

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < 0 and ptpn6_score < 0 and ntrk1_score > 0):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]
compareExpression('TMPRSS2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=2.564e-02 stat=-2.251e+00
# Activated v.s. Not activated: t-test independent samples, P_val=2.564e-02 stat=-2.251e+00
# Activated: median = -0.47474703982144784, mean = -0.3444566599228923
# Not activated: median = -0.31637038532044914, mean = 0.08076914784398824

# %%
compareExpression('IFITM2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.112e-07 stat=-5.386e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.112e-07 stat=-5.386e+00
# Activated: median = -0.4127749550162723, mean = -0.42421775099723674
# Not activated: median = 0.17157733480981865, mean = 0.13027159282592318

# %%
compareExpression('CXCL10',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=2.896e-06 stat=-4.733e+00
# Activated v.s. Not activated: t-test independent samples, P_val=2.896e-06 stat=-4.733e+00
# Activated: median = -0.3476097210559111, mean = -0.374220216767028
# Not activated: median = 0.1466427441141226, mean = 0.1170688913415569

# %%
compareExpression('CXCL11',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.508e-07 stat=-5.338e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.508e-07 stat=-5.338e+00
# Activated: median = -0.5653421915134907, mean = -0.461733406533643
# Not activated: median = 0.008692339410212448, mean = 0.13230957263244741

# %%
compareExpression('AGTR1',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=7.802e-01 stat=2.792e-01
# Activated v.s. Not activated: t-test independent samples, P_val=7.802e-01 stat=2.792e-01
# Activated: median = 0.04441903782759274, mean = 0.02258574467494377
# Not activated: median = -0.022063837541672023, mean = -0.007028010975979892

# %%
compareExpression('BSG',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.349e-04 stat=-3.848e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.349e-04 stat=-3.848e+00
# Activated: median = -0.42185684756246455, mean = -0.3072070056159075
# Not activated: median = 0.046254210814887516, mean = 0.09433915920488502

# %%
compareExpression('DPP4',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.665e-03 stat=-3.162e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.665e-03 stat=-3.162e+00
# Activated: median = -0.12368461105761287, mean = -0.25362842472287117
# Not activated: median = 0.20118393821679034, mean = 0.07788589420623598

# %%
compareExpression('PPIA',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=4.802e-05 stat=-4.101e+00
# Activated v.s. Not activated: t-test independent samples, P_val=4.802e-05 stat=-4.101e+00
# Activated: median = -0.483082611196022, mean = -0.32681628070224045
# Not activated: median = -0.09895508612404393, mean = 0.10036090509753727

# %%
compareExpression('PPIB',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.243e-08 stat=-5.791e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.243e-08 stat=-5.791e+00
# Activated: median = -0.5459564449785677, mean = -0.4541277991355144
# Not activated: median = 0.07594893495253294, mean = 0.13945656823846433
