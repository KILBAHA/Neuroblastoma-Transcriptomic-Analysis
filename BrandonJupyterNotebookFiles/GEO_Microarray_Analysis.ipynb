# %%
from ipynb.fs.full.GEO_Microarray_Analysis_Functions import *

# %% [markdown]
# # EFS Analysis

# %%
groups = stratifyDataOnGeneExpression('ACE2',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by ACE2 Expression', ['Low ACE2','High ACE2'], 't-test_ind')
kaplanmeierEFS(groups, 'Low ACE2', 'High ACE2')
# Out:
# Low ACE2 v.s. High ACE2: t-test independent samples, P_val=1.774e-01 stat=1.352e+00
# Low ACE2: median = 1890.0, mean = 2016.8840579710145, 95% CI = (1777.003288501126, 2256.764827440903)
# High ACE2: median = 1364.5, mean = 1795.1, 95% CI = (1585.4362337506673, 2004.7637662493325)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            5.07 0.02      5.36
# p-value = 0.024277058121605348

# %%
groups = stratifyDataOnGeneExpression2('ACE2',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by ACE2 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=138) median survival time = inf
# Low (n=138) probability of 5yr EFS = 0.7330529461184248
# Intermediate (n=159) median survival time = inf
# Intermediate (n=159) probability of 5yr EFS = 0.5745635058582302
# High (n=200) median survival time = inf
# High (n=200) probability of 5yr EFS = 0.5941455092643206
# Log Rank Test between Low (n=138) and Intermediate (n=159)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            5.78 0.02      5.94
# p-value = 0.016244052702119115
# Log Rank Test between Low (n=138) and High (n=200)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            5.07 0.02      5.36
# p-value = 0.024277058121605348
# ...

# %%
groups = stratifyDataOnGeneExpression('TMPRSS2',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by TMPRSS2 Expression', ['Low TMPRSS2','High TMPRSS2'], 't-test_ind')
kaplanmeierEFS(groups, 'Low TMPRSS2', 'High TMPRSS2')
# Out:
# Low TMPRSS2 v.s. High TMPRSS2: t-test independent samples, P_val=7.218e-01 stat=-3.564e-01
# Low TMPRSS2: median = 1576.0, mean = 1811.5133689839572, 95% CI = (1601.7409279782564, 2021.285809989658)
# High TMPRSS2: median = 1483.0, mean = 1867.2485549132948, 95% CI = (1643.311715254457, 2091.1853945721323)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.00 0.98      0.03
# p-value = 0.9817763252790752

# %%
groups = stratifyDataOnGeneExpression2('TMPRSS2',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by TMPRSS2 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=187) median survival time = inf
# Low (n=187) probability of 5yr EFS = 0.6265110569631944
# Intermediate (n=137) median survival time = inf
# Intermediate (n=137) probability of 5yr EFS = 0.6208471310641226
# High (n=173) median survival time = inf
# High (n=173) probability of 5yr EFS = 0.6323043313776227
# Log Rank Test between Low (n=187) and Intermediate (n=137)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.05 0.82      0.28
# p-value = 0.8212115617316433
# Log Rank Test between Low (n=187) and High (n=173)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.00 0.98      0.03
# p-value = 0.9817763252790752
# ...

# %%
groups = stratifyDataOnGeneExpression('IFITM2',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by IFITM2 Expression', ['Low IFITM2','High IFITM2'], 't-test_ind')
kaplanmeierEFS(groups, 'Low IFITM2', 'High IFITM2')
# Out:
# Low IFITM2 v.s. High IFITM2: t-test independent samples, P_val=5.768e-01 stat=-5.586e-01
# Low IFITM2: median = 1406.0, mean = 1683.8255033557048, 95% CI = (1452.5283073750763, 1915.1226993363332)
# High IFITM2: median = 1440.0, mean = 1775.0805369127518, 95% CI = (1553.7133510811225, 1996.447722744381)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.62 0.20      2.30
# p-value = 0.20330150004105146

# %%
groups = stratifyDataOnGeneExpression2('IFITM2',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by IFITM2 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=149) median survival time = inf
# Low (n=149) probability of 5yr EFS = 0.5700221068208406
# Intermediate (n=200) median survival time = inf
# Intermediate (n=200) probability of 5yr EFS = 0.6675473357912834
# High (n=148) median survival time = inf
# High (n=148) probability of 5yr EFS = 0.6276571548031966
# Log Rank Test between Low (n=149) and Intermediate (n=200)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            2.34 0.13      2.98
# p-value = 0.126315627816645
# Log Rank Test between Low (n=149) and High (n=148)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.79 0.18      2.46
# p-value = 0.18146660402519738
# ...

# %%
groups = stratifyDataOnGeneExpression('IFITM3',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by IFITM3 Expression', ['Low IFITM3','High IFITM3'], 't-test_ind')
kaplanmeierEFS(groups, 'Low IFITM3', 'High IFITM3')
# Out:
# Low IFITM3 v.s. High IFITM3: t-test independent samples, P_val=5.978e-01 stat=5.281e-01
# Low IFITM3: median = 1467.0, mean = 1748.4155844155844, 95% CI = (1515.1322735250892, 1981.6988953060795)
# High IFITM3: median = 1211.0, mean = 1661.76821192053, 95% CI = (1440.7500018951116, 1882.7864219459482)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.03 0.86      0.21
# p-value = 0.8634398714075882

# %%
groups = stratifyDataOnGeneExpression2('IFITM3',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by IFITM3 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=154) median survival time = inf
# Low (n=154) probability of 5yr EFS = 0.5928579852377196
# Intermediate (n=193) median survival time = inf
# Intermediate (n=193) probability of 5yr EFS = 0.6914518267607042
# High (n=150) median survival time = inf
# High (n=150) probability of 5yr EFS = 0.5748305892653356
# Log Rank Test between Low (n=154) and Intermediate (n=193)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            3.85 0.05      4.33
# p-value = 0.04966956799616721
# Log Rank Test between Low (n=154) and High (n=150)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.05 0.82      0.29
# p-value = 0.8178887939681062
# ...

# %%
groups = stratifyDataOnGeneExpression('CXCL10',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by CXCL10 Expression', ['Low CXCL10','High CXCL10'], 't-test_ind')
kaplanmeierEFS(groups, 'Low CXCL10', 'High CXCL10')
# Out:
# Low CXCL10 v.s. High CXCL10: t-test independent samples, P_val=2.233e-01 stat=-1.221e+00
# Low CXCL10: median = 1145.5, mean = 1546.4545454545455, 95% CI = (1299.2485777795175, 1793.6605131295735)
# High CXCL10: median = 1537.0, mean = 1758.1301369863013, 95% CI = (1529.3647187058173, 1986.8955552667853)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.08 0.77      0.37
# p-value = 0.7741002117537689

# %%
groups = stratifyDataOnGeneExpression2('CXCL10',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by CXCL10 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=110) median survival time = inf
# Low (n=110) probability of 5yr EFS = 0.5816415026703606
# Intermediate (n=242) median survival time = inf
# Intermediate (n=242) probability of 5yr EFS = 0.6690764472142363
# High (n=145) median survival time = inf
# High (n=145) probability of 5yr EFS = 0.5897966400111498
# Log Rank Test between Low (n=110) and Intermediate (n=242)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            2.73 0.10      3.35
# p-value = 0.09817200696800209
# Log Rank Test between Low (n=110) and High (n=145)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.12 0.73      0.45
# p-value = 0.7344302353433343
# ...

# %%
groups = stratifyDataOnGeneExpression('CXCL11',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by CXCL11 Expression', ['Low CXCL11','High CXCL11'], 't-test_ind')
kaplanmeierEFS(groups, 'Low CXCL11', 'High CXCL11')
# Out:
# Low CXCL11 v.s. High CXCL11: t-test independent samples, P_val=3.392e-01 stat=9.575e-01
# Low CXCL11: median = 1704.5, mean = 1752.1530612244899, 95% CI = (1469.354108931675, 2034.9520135173047)
# High CXCL11: median = 1110.0, mean = 1581.7391304347825, 95% CI = (1370.9074481276311, 1792.5708127419339)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.50 0.22      2.18
# p-value = 0.22018419206868847

# %%
groups = stratifyDataOnGeneExpression2('CXCL11',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by CXCL11 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=98) median survival time = inf
# Low (n=98) probability of 5yr EFS = 0.6423541164265206
# Intermediate (n=239) median survival time = inf
# Intermediate (n=239) probability of 5yr EFS = 0.6762956260123725
# High (n=160) median survival time = inf
# High (n=160) probability of 5yr EFS = 0.5437436940052872
# Log Rank Test between Low (n=98) and Intermediate (n=239)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.65 0.42      1.25
# p-value = 0.4193796234606131
# Log Rank Test between Low (n=98) and High (n=160)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.40 0.24      2.08
# p-value = 0.23667961890875222
# ...

# %%
groups = stratifyDataOnGeneExpression('AGTR1',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by AGTR1 Expression', ['Low AGTR1','High AGTR1'], 't-test_ind')
kaplanmeierEFS(groups, 'Low AGTR1', 'High AGTR1')
# Out:
# Low AGTR1 v.s. High AGTR1: t-test independent samples, P_val=4.599e-03 stat=-2.857e+00
# Low AGTR1: median = 1211.0, mean = 1559.0238095238096, 95% CI = (1322.1525272895221, 1795.8950917580971)
# High AGTR1: median = 1925.0, mean = 2059.9113924050635, 95% CI = (1818.0664647547285, 2301.756320055398)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            4.52 0.03      4.90
# p-value = 0.03345761823654383

# %%
groups = stratifyDataOnGeneExpression2('AGTR1',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by AGTR1 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=125) median survival time = inf
# Low (n=125) probability of 5yr EFS = 0.5873625387659215
# Intermediate (n=214) median survival time = inf
# Intermediate (n=214) probability of 5yr EFS = 0.5865916257236312
# High (n=158) median survival time = inf
# High (n=158) probability of 5yr EFS = 0.7094600557923895
# Log Rank Test between Low (n=125) and Intermediate (n=214)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.08 0.77      0.38
# p-value = 0.7709639739503957
# Log Rank Test between Low (n=125) and High (n=158)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            4.20 0.04      4.63
# p-value = 0.04036995313483157
# ...

# %%
groups = stratifyDataOnGeneExpression('BSG',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by CD147 Expression', ['Low CD147','High CD147'], 't-test_ind')
kaplanmeierEFS(groups, 'Low CD147', 'High CD147')
# Out:
# Low CD147 v.s. High CD147: t-test independent samples, P_val=2.290e-10 stat=6.555e+00
# Low CD147: median = 2256.0, mean = 2321.934523809524, 95% CI = (2108.1652019179724, 2535.7038457010754)
# High CD147: median = 634.0, mean = 1291.7074829931973, 95% CI = (1070.9093753603697, 1512.505590626025)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           58.41 <0.005     45.42
# p-value = 2.1312487528410765e-14

# %%
groups = stratifyDataOnGeneExpression2('BSG',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by CD147 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=167) median survival time = inf
# Low (n=167) probability of 5yr EFS = 0.8157037570303391
# Intermediate (n=183) median survival time = inf
# Intermediate (n=183) probability of 5yr EFS = 0.6507772011525157
# High (n=147) median survival time = 1.83013698630137
# High (n=147) probability of 5yr EFS = 0.3812965060884443
# Log Rank Test between Low (n=167) and Intermediate (n=183)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           10.77 <0.005      9.92
# p-value = 0.001030153273024751
# Log Rank Test between Low (n=167) and High (n=147)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           59.48 <0.005     46.20
# ...

# %%
groups = stratifyDataOnGeneExpression('DPP4',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by DPP4 Expression', ['Low DPP4','High DPP4'], 't-test_ind')
kaplanmeierEFS(groups, 'Low DPP4', 'High DPP4')
# Out:
# Low DPP4 v.s. High DPP4: t-test independent samples, P_val=1.447e-04 stat=-3.853e+00
# Low DPP4: median = 633.5, mean = 1409.7846153846153, 95% CI = (1161.6856325704157, 1657.883598198815)
# High DPP4: median = 1814.0, mean = 2076.3766233766232, 95% CI = (1845.699609621434, 2307.0536371318126)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           21.55 <0.005     18.15
# p-value = 3.4472098449166954e-06

# %%
groups = stratifyDataOnGeneExpression2('DPP4',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by DPP4 expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=130) median survival time = 2.3013698630136985
# Low (n=130) probability of 5yr EFS = 0.44666541907845153
# Intermediate (n=214) median survival time = inf
# Intermediate (n=214) probability of 5yr EFS = 0.6691713043887136
# High (n=153) median survival time = inf
# High (n=153) probability of 5yr EFS = 0.7158368118323204
# Log Rank Test between Low (n=130) and Intermediate (n=214)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           15.89 <0.005     13.86
# p-value = 6.725061078186535e-05
# Log Rank Test between Low (n=130) and High (n=153)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           22.10 <0.005     18.56
# ...

# %%
groups = stratifyDataOnGeneExpression('PPIA',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by PPIA Expression', ['Low PPIA','High PPIA'], 't-test_ind')
kaplanmeierEFS(groups, 'Low PPIA', 'High PPIA')
# Out:
# Low PPIA v.s. High PPIA: t-test independent samples, P_val=1.433e-16 stat=8.765e+00
# Low PPIA: median = 2390.0, mean = 2422.323529411765, 95% CI = (2213.9845256073277, 2630.662533216202)
# High PPIA: median = 602.0, mean = 1091.6412213740457, 95% CI = (887.2039656307952, 1296.0784771172962)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           66.72 <0.005     51.51
# p-value = 3.126352379055503e-16

# %%
groups = stratifyDataOnGeneExpression2('PPIA',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by PPIA expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=170) median survival time = inf
# Low (n=170) probability of 5yr EFS = 0.8261835374928874
# Intermediate (n=196) median survival time = inf
# Intermediate (n=196) probability of 5yr EFS = 0.6137819045504415
# High (n=131) median survival time = 1.8
# High (n=131) probability of 5yr EFS = 0.3694004362681878
# Log Rank Test between Low (n=170) and Intermediate (n=196)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           18.83 <0.005     16.09
# p-value = 1.4324720560190888e-05
# Log Rank Test between Low (n=170) and High (n=131)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           66.72 <0.005     51.51
# p-value = 3.126352379055503e-16
# ...

# %%
groups = stratifyDataOnGeneExpression('PPIB',-0.5,0.5)
compareEFS(groups, 'EFS Stratified by PPIB Expression', ['Low PPIB','High PPIB'], 't-test_ind')
kaplanmeierEFS(groups, 'Low PPIB', 'High PPIB')
# Out:
# Low PPIB v.s. High PPIB: t-test independent samples, P_val=7.101e-11 stat=6.758e+00
# Low PPIB: median = 2217.0, mean = 2287.042424242424, 95% CI = (2050.780345108589, 2523.3045033762596)
# High PPIB: median = 748.5, mean = 1215.5281690140846, 95% CI = (1023.6196045207575, 1407.4367335074116)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           38.56 <0.005     30.81
# p-value = 5.312218420176394e-10

# %%
groups = stratifyDataOnGeneExpression2('PPIB',-0.5,0.5)
kaplanmeierEFS2(groups, 'EFS stratified by PPIB expression',['Low (n='+str(len(groups[0]))+')','Intermediate (n='+str(len(groups[1]))+')','High (n='+str(len(groups[2]))+')'])
# Out:
# Low (n=164) median survival time = inf
# Low (n=164) probability of 5yr EFS = 0.7512398531494131
# Intermediate (n=191) median survival time = inf
# Intermediate (n=191) probability of 5yr EFS = 0.7060285443075532
# High (n=142) median survival time = 2.282191780821918
# High (n=142) probability of 5yr EFS = 0.3770291177977043
# Log Rank Test between Low (n=164) and Intermediate (n=191)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.02 0.31      1.68
# p-value = 0.3118500398595347
# Log Rank Test between Low (n=164) and High (n=142)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           39.41 <0.005     31.44
# p-value = 3.4303687385439355e-10
# ...

# %% [markdown]
# # MYCN Amplification Analysis

# %%
MYCN_groups = stratifyClinicalData('MYCN Amplification',[0,1])
compareExpression('ACE2',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=2.554e-03 stat=-3.032e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=2.554e-03 stat=-3.032e+00
# Not Amplified: median = 0.2146730002395654, mean = -0.06987304487014635
# Amplified: median = 0.5633140636997496, mean = 0.27719139884062466

# %%
compareExpression('TMPRSS2',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.360e-02 stat=2.476e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.360e-02 stat=2.476e+00
# Not Amplified: median = 0.08583329961604051, mean = 0.039091109542143836
# Amplified: median = -0.29480195365795553, mean = -0.24097787070819904

# %%
compareExpression('IFITM2',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.876e-06 stat=4.671e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.876e-06 stat=4.671e+00
# Not Amplified: median = 0.028223475318944518, mean = 0.09867220305992029
# Amplified: median = -0.419714259735993, mean = -0.431940579557542

# %%
compareExpression('IFITM3',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.440e-02 stat=2.456e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.440e-02 stat=2.456e+00
# Not Amplified: median = -0.008480557854046259, mean = 0.046905459610586446
# Amplified: median = -0.13929128652314776, mean = -0.23526654940536892

# %%
compareExpression('CXCL10',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.934e-13 stat=7.564e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.934e-13 stat=7.564e+00
# Not Amplified: median = 0.11041253922597724, mean = 0.15158193858313598
# Amplified: median = -0.4029523714605232, mean = -0.673605032380791

# %%
compareExpression('CXCL11',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.073e-04 stat=3.905e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.073e-04 stat=3.905e+00
# Not Amplified: median = 0.2174550913838187, mean = 0.08172574654270733
# Amplified: median = -0.07909988884962268, mean = -0.36225882254513325

# %%
compareExpression('AGTR1',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=6.154e-03 stat=2.751e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=6.154e-03 stat=2.751e+00
# Not Amplified: median = 0.1531764173238165, mean = 0.0574593827137974
# Amplified: median = -0.2843722594248974, mean = -0.2581110675784481

# %%
compareExpression('BSG',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.725e-14 stat=-7.909e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.725e-14 stat=-7.909e+00
# Not Amplified: median = -0.2378530316404273, mean = -0.1594870199457581
# Amplified: median = 0.6857172378816618, mean = 0.7045241173380821

# %%
compareExpression2('BSG',MYCN_groups,'MYCN amplification','CD147 expression stratified by MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.725e-14 stat=-7.909e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.725e-14 stat=-7.909e+00
# Not Amplified: median = -0.2378530316404273, mean = -0.1594870199457581
# Amplified: median = 0.6857172378816618, mean = 0.7045241173380821

# %%
compareExpression('DPP4',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.973e-25 stat=1.103e+01
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.973e-25 stat=1.103e+01
# Not Amplified: median = 0.26588200532018985, mean = 0.20940083645147683
# Amplified: median = -0.8135411358438427, mean = -0.9303208324025247

# %%
compareExpression('PPIA',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=2.313e-21 stat=-9.948e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=2.313e-21 stat=-9.948e+00
# Not Amplified: median = -0.3526804897076534, mean = -0.19294007151621936
# Amplified: median = 0.7322133814113285, mean = 0.8598781138823237

# %%
compareExpression('PPIB',MYCN_groups,'MYCN amplification',['Not Amplified','Amplified'], 't-test_ind')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.121e-13 stat=-7.495e+00
# Not Amplified v.s. Amplified: t-test independent samples, P_val=3.121e-13 stat=-7.495e+00
# Not Amplified: median = -0.2090383234425358, mean = -0.15281105923566887
# Amplified: median = 0.6359004368899426, mean = 0.6658431743764102

# %% [markdown]
# # MYCN Expression Analysis

# %%
geneScatter('ACE2','MYCN')
# Out:
# Pearson correlation coefficient = 0.07701356759728965
# p-value = 0.08600477996407861

# %%
geneScatter('TMPRSS2','MYCN')
# Out:
# Pearson correlation coefficient = -0.14322862559541025
# p-value = 0.00135163933257567

# %%
geneScatter('IFITM2','MYCN')
# Out:
# Pearson correlation coefficient = -0.31383546092631087
# p-value = 7.620893514265243e-13

# %%
geneScatter('IFITM3','MYCN')
# Out:
# Pearson correlation coefficient = -0.22437874426040433
# p-value = 4.2083309306046443e-07

# %%
geneScatter('CXCL10','MYCN')
# Out:
# Pearson correlation coefficient = -0.3601896984443384
# p-value = 1.0596426826653206e-16

# %%
geneScatter('CXCL11','MYCN')
# Out:
# Pearson correlation coefficient = -0.2399511888243785
# p-value = 5.9377632272870055e-08

# %%
geneScatter('AGTR1','MYCN')
# Out:
# Pearson correlation coefficient = -0.13552785158753314
# p-value = 0.0024388845782916165

# %%
geneScatter('BSG','MYCN')
# Out:
# Pearson correlation coefficient = 0.30188659154533476
# p-value = 5.937733038313656e-12

# %%
geneScatter('DPP4','MYCN')
# Out:
# Pearson correlation coefficient = -0.4743610773305864
# p-value = 2.625297036427535e-29

# %%
geneScatter('PPIA','MYCN')
# Out:
# Pearson correlation coefficient = 0.4050484472568139
# p-value = 4.375396369951508e-21

# %%
geneScatter('PPIB','MYCN')
# Out:
# Pearson correlation coefficient = 0.3052014791713134
# p-value = 3.3909341342588026e-12

# %% [markdown]
# # TP53/PTPN6/NTRK1 Pathway Analysis

# %%
#using z-score cutoff of 0 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['#Gene']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['#Gene']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['#Gene']=='NTRK1'][sample].values[0]
    if(tp53_score < 0 and ptpn6_score < 0 and ntrk1_score > 0):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]

# %%
compareExpression('ACE2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.388e-03 stat=-3.215e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.388e-03 stat=-3.215e+00
# Activated: median = -0.03663172570635402, mean = -0.2521318905350804
# Not activated: median = 0.3597926307153781, mean = 0.08148036585955291

# %%
compareExpression('TMPRSS2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.942e-03 stat=-3.116e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.942e-03 stat=-3.116e+00
# Activated: median = -0.4513248615463277, mean = -0.24549900164277885
# Not activated: median = 0.2156761663870765, mean = 0.07792389735572386

# %%
compareExpression('IFITM2',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.485e-07 stat=-5.331e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.485e-07 stat=-5.331e+00
# Activated: median = -0.419714259735993, mean = -0.4124748619977324
# Not activated: median = 0.16260479583542575, mean = 0.13073026669794655

# %%
compareExpression('IFITM3',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.573e-07 stat=-5.320e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.573e-07 stat=-5.320e+00
# Activated: median = -0.4195999908140791, mean = -0.4115691078261292
# Not activated: median = 0.11765835907687233, mean = 0.1306300916690583

# %%
compareExpression('CXCL10',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.373e-02 stat=-2.473e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.373e-02 stat=-2.473e+00
# Activated: median = -0.1739694616579114, mean = -0.19670903347915175
# Not activated: median = 0.16211835756850265, mean = 0.06073998539654167

# %%
compareExpression('CXCL11',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.291e-04 stat=-3.859e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.291e-04 stat=-3.859e+00
# Activated: median = -0.05984307195134723, mean = -0.3031898225733004
# Not activated: median = 0.26238766414646125, mean = 0.09499675895943106

# %%
compareExpression('AGTR1',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=9.551e-01 stat=5.627e-02
# Activated v.s. Not activated: t-test independent samples, P_val=9.551e-01 stat=5.627e-02
# Activated: median = 0.0923000796892128, mean = 0.005607898460595814
# Not activated: median = 0.09039769413813148, mean = -0.00028942984480051265

# %%
compareExpression('BSG',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.831e-04 stat=-3.770e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.831e-04 stat=-3.770e+00
# Activated: median = -0.401523712315228, mean = -0.29292522053336284
# Not activated: median = 0.1011790926145188, mean = 0.09645303952512368

# %%
compareExpression2('BSG',data,'TrkA Pathway Activation','CD147 Expression stratified by TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.831e-04 stat=-3.770e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.831e-04 stat=-3.770e+00
# Activated: median = -0.401523712315228, mean = -0.2929252205333629
# Not activated: median = 0.1011790926145188, mean = 0.09645303952512371

# %%
compareExpression('DPP4',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.405e-02 stat=-2.465e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.405e-02 stat=-2.465e+00
# Activated: median = -0.0813008763407558, mean = -0.19596773943478452
# Not activated: median = 0.22485130112389706, mean = 0.06062775429568694

# %%
compareExpression('PPIA',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.994e-05 stat=-4.307e+00
# Activated v.s. Not activated: t-test independent samples, P_val=1.994e-05 stat=-4.307e+00
# Activated: median = -0.42343443782410295, mean = -0.33630767526747934
# Not activated: median = -0.02249539849752776, mean = 0.10690654739276303

# %%
compareExpression('PPIB',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=6.646e-07 stat=-5.037e+00
# Activated v.s. Not activated: t-test independent samples, P_val=6.646e-07 stat=-5.037e+00
# Activated: median = -0.3710813733693131, mean = -0.38715175848601924
# Not activated: median = 0.0918987692786184, mean = 0.12729951156885327

# %% [markdown]
# # Age at Diagnosis Analysis

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('ACE2',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=1.422e-02 stat=-2.460e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=1.422e-02 stat=-2.460e+00
# <18 months: median = 0.15804094932217505, mean = -0.08734526310573835
# >=18 months: median = 0.4482802102738005, mean = 0.1380326696748718

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('TMPRSS2',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.614e-01 stat=7.371e-01
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.614e-01 stat=7.371e-01
# <18 months: median = 0.0431452338283026, mean = 0.026314939038219107
# >=18 months: median = 0.1391933818507128, mean = -0.041585784490449924

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('IFITM2',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=3.581e-01 stat=9.198e-01
# <18 months v.s. >=18 months: t-test independent samples, P_val=3.581e-01 stat=9.198e-01
# <18 months: median = 0.05808599098927486, mean = 0.032825240028798205
# >=18 months: median = -0.12108910303270368, mean = -0.051874083983337954

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('IFITM3',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=9.892e-01 stat=-1.357e-02
# <18 months v.s. >=18 months: t-test independent samples, P_val=9.892e-01 stat=-1.357e-02
# <18 months: median = -0.008480557854046259, mean = -0.00048486694476481285
# >=18 months: median = -0.017824181330412078, mean = 0.0007662405085724136

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('CXCL10',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=7.865e-01 stat=2.709e-01
# <18 months v.s. >=18 months: t-test independent samples, P_val=7.865e-01 stat=2.709e-01
# <18 months: median = 0.010694175279678713, mean = 0.009677011640153726
# >=18 months: median = 0.10302599374847378, mean = -0.015292686788844226

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('CXCL11',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.570e-03 stat=-2.849e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.570e-03 stat=-2.849e+00
# <18 months: median = 0.12245479468565976, mean = -0.1009326996149461
# >=18 months: median = 0.2996175101497938, mean = 0.1595050434329463

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('AGTR1',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=9.912e-03 stat=2.589e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=9.912e-03 stat=2.589e+00
# <18 months: median = 0.19122412834544367, mean = 0.09185099195256399
# >=18 months: median = -0.13218141533838815, mean = -0.14515312199757519

# %%
groups = stratifyDataOnAge(547.5)
compareExpression2('BSG',groups,'Age at Diagnosis','CD147 Expression stratified by Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=1.189e-06 stat=-4.918e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=1.189e-06 stat=-4.918e+00
# <18 months: median = -0.2378530316404273, mean = -0.17154149122651338
# >=18 months: median = 0.3466851136267157, mean = 0.27108888509890466

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('DPP4',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.415e-12 stat=7.098e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.415e-12 stat=7.098e+00
# <18 months: median = 0.2911316694409865, mean = 0.24154298482342293
# >=18 months: median = -0.20754919694473695, mean = -0.3817130071043728

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('PPIA',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.599e-13 stat=-7.436e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=4.599e-13 stat=-7.436e+00
# <18 months: median = -0.3526804897076534, mean = -0.2519237745210487
# >=18 months: median = 0.3076896927125979, mean = 0.3981178820151481

# %%
groups = stratifyDataOnAge(547.5)
compareExpression('PPIB',groups,'Age at Diagnosis',['<18 months','>=18 months'],'t-test_ind')
# Out:
# <18 months v.s. >=18 months: t-test independent samples, P_val=3.231e-04 stat=-3.621e+00
# <18 months v.s. >=18 months: t-test independent samples, P_val=3.231e-04 stat=-3.621e+00
# <18 months: median = -0.13959130204535145, mean = -0.12767525575096633
# >=18 months: median = 0.23079281207299535, mean = 0.20176659587590048
