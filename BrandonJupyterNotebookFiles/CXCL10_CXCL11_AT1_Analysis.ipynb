# %%
from ipynb.fs.full.TARGET_Analysis_Functions import *
from ipynb.fs.full.ACE2_SCA_Analysis import *

# %%
#Stratify samples based on MYCN amplification
MYCN_groups = stratifyCategoricalSampleData('MYCN', 'Not Amplified', 'Amplified')

#Find z-scores for MYCN nonamplified samples
nonamplified_MYCN_columns = ['Hugo_Symbol','Entrez_Gene_Id'] + list(set(MYCN_groups[0]).intersection(z_scores.columns))
nonamplified_MYCN_z_scores = z_scores[nonamplified_MYCN_columns]

# %% [markdown]
# # EFS Analysis

# %%
CXCL10_groups = stratifyDataOnGeneExpression('CXCL10',-0.5,0.5)
compareEFS2(CXCL10_groups, 'EFS stratified by CXCL10 expression', ['Low CXCL10','High CXCL10'], 't-test_ind')
kaplanmeierEFS(CXCL10_groups,'Low CXCL10','High CXCL10')
# Out:
# Low CXCL10 v.s. High CXCL10: t-test independent samples, P_val=5.331e-01 stat=6.247e-01
# Low CXCL10: median = 691.5, mean = 1503.825, 95% CI = (1176.13922222956, 1831.5107777704402)
# High CXCL10: median = 684.0, mean = 1360.2394366197184, 95% CI = (1056.41279914367, 1664.0660740957667)

# %%
CXCL11_groups = stratifyDataOnGeneExpression('CXCL11',-0.5,0.5)
compareEFS2(CXCL11_groups, 'EFS stratified by CXCL11 expression', ['Low CXCL11','High CXCL11'], 't-test_ind')
kaplanmeierEFS(CXCL11_groups,'Low CXCL11','High CXCL11')
# Out:
# Low CXCL11 v.s. High CXCL11: t-test independent samples, P_val=5.941e-02 stat=1.900e+00
# Low CXCL11: median = 1002.0, mean = 1710.4507042253522, 95% CI = (1356.292359335091, 2064.6090491156133)
# High CXCL11: median = 646.0, mean = 1270.5064935064936, 95% CI = (981.8960224239294, 1559.1169645890577)

# %%
AGTR1_groups = stratifyDataOnGeneExpression('AGTR1',-0.5,0.5)
compareEFS2(AGTR1_groups, 'EFS stratified by AGTR1 expression', ['Low AGTR1','High AGTR1'], 't-test_ind')
kaplanmeierEFS(AGTR1_groups,'Low AGTR1','High AGTR1')
# Out:
# Low AGTR1 v.s. High AGTR1: t-test independent samples, P_val=6.130e-01 stat=-5.069e-01
# Low AGTR1: median = 676.0, mean = 1401.9318181818182, 95% CI = (1104.0610710336673, 1699.8025653299692)
# High AGTR1: median = 798.0, mean = 1524.5964912280701, 95% CI = (1156.0623812832603, 1893.13060117288)

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
CXCL10_groups = stratifyDataOnGeneExpression('CXCL10',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(CXCL10_groups, 'EFS in MYCN nonamplified samples stratified by CXCL10 expression', ['Low CXCL10','High CXCL10'], 't-test_ind')
kaplanmeierEFS(CXCL10_groups,'Low CXCL10','High CXCL10')
# Out:
# Low CXCL10 v.s. High CXCL10: t-test independent samples, P_val=1.705e-01 stat=1.381e+00
# Low CXCL10: median = 1242.5, mean = 1817.642857142857, 95% CI = (1316.0084046638506, 2319.2773096218634)
# High CXCL10: median = 692.0, mean = 1398.4035087719299, 95% CI = (1045.5578175130327, 1751.249200030827)

# %%
CXCL11_groups = stratifyDataOnGeneExpression('CXCL11',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(CXCL11_groups, 'EFS in MYCN nonamplified samples stratified by CXCL11 expression', ['Low CXCL11','High CXCL11'], 't-test_ind')
kaplanmeierEFS(CXCL11_groups,'Low CXCL11','High CXCL11')
# Out:
# Low CXCL11 v.s. High CXCL11: t-test independent samples, P_val=7.458e-03 stat=2.730e+00
# Low CXCL11: median = 1795.0, mean = 2098.6511627906975, 95% CI = (1618.61593424667, 2578.686391334725)
# High CXCL11: median = 665.0, mean = 1305.0, 95% CI = (966.5929856888781, 1643.4070143111219)

# %%
AGTR1_groups = stratifyDataOnGeneExpression('AGTR1',-0.5,0.5,z_scores=nonamplified_MYCN_z_scores)
compareEFS2(AGTR1_groups, 'EFS in MYCN nonamplified samples stratified by AGTR1 expression', ['Low AGTR1','High AGTR1'], 't-test_ind')
kaplanmeierEFS(AGTR1_groups,'Low AGTR1','High AGTR1')
# Out:
# Low AGTR1 v.s. High AGTR1: t-test independent samples, P_val=8.856e-01 stat=-1.442e-01
# Low AGTR1: median = 751.0, mean = 1557.358208955224, 95% CI = (1192.9016098932339, 1921.814808017214)
# High AGTR1: median = 922.0, mean = 1598.7555555555555, 95% CI = (1178.5821861971465, 2018.9289249139645)

# %% [markdown]
# # MYCN Analysis

# %%
MYCN_groups = stratifyCategoricalSampleData('MYCN', 'Not Amplified', 'Amplified')
compareExpression2('CXCL10', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
geneScatter('CXCL10','MYCN')
compareExpression2('CXCL11', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
geneScatter('CXCL11','MYCN')
compareExpression2('AGTR1', MYCN_groups,'MYCN Amplification',['Not Amplified','Amplified'],'t-test_ind')
geneScatter('AGTR1','MYCN')
# Out:
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.641e-05 stat=4.398e+00
# Not Amplified: median = 0.0194, mean = 0.15939428571428574, 95% CI = (0.017324848404660254, 0.3014637230239112)
# Amplified: median = -0.6893, mean = -0.45160000000000006, 95% CI = (-0.6907036109809712, -0.2124963890190289)
# Pearson correlation coefficient = -0.33432469111150254
# p-value = 6.468285581897046e-08
# Not Amplified v.s. Amplified: t-test independent samples, P_val=6.981e-04 stat=3.435e+00
# Not Amplified: median = -0.0021, mean = 0.1253817142857143, 95% CI = (-0.018673704203815283, 0.26943713277524384)
# Amplified: median = -0.3385, mean = -0.356810294117647, 95% CI = (-0.5964346635135176, -0.11718592472177641)
# Pearson correlation coefficient = -0.26941215249171346
# p-value = 1.6339056105587384e-05
# Not Amplified v.s. Amplified: t-test independent samples, P_val=1.673e-01 stat=1.385e+00
# ...

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
geneScatter('CXCL10','MYCN',z_scores=nonamplified_MYCN_z_scores)
geneScatter('CXCL11','MYCN',z_scores=nonamplified_MYCN_z_scores)
geneScatter('AGTR1','MYCN',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.1542150118928669
# p-value = 0.04158406858080125
# Pearson correlation coefficient = -0.1563653277050076
# p-value = 0.038788521047524054
# Pearson correlation coefficient = -0.12588381251614564
# p-value = 0.09692206055965685

# %% [markdown]
# # SCA Analysis

# %%
#1p loss
compareExpression2('CXCL10',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')

#11q loss
compareExpression2('CXCL10',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')

#17q gain
compareExpression2('CXCL10',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')

#All three SCAs
compareExpression2('CXCL10',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=2.088e-02 stat=2.381e+00
# No Loss: median = 0.20205, mean = 0.3024675, 95% CI = (0.03010416440587982, 0.5748308355941202)
# Loss: median = -0.7425, mean = -0.3615466666666667, 95% CI = (-0.8824593307657086, 0.15936599743237523)
# No Loss v.s. Loss: t-test independent samples, P_val=5.142e-02 stat=-1.993e+00
# No Loss: median = -0.027749999999999997, mean = -0.12527142857142856, 95% CI = (-0.5021279300760738, 0.25158507293321664)
# Loss: median = 0.3721, mean = 0.37715185185185185, 95% CI = (0.06027659412215991, 0.6940271095815438)
# No Gain v.s. Gain: t-test independent samples, P_val=2.984e-01 stat=-1.050e+00
# No Gain: median = 0.0834, mean = -0.007220689655172388, 95% CI = (-0.353881558628964, 0.33944017931861925)
# Gain: median = 0.11485000000000001, mean = 0.2648038461538461, 95% CI = (-0.10669295987689215, 0.6363006521845844)
# No SCA v.s. SCA: t-test independent samples, P_val=9.408e-01 stat=7.467e-02
# ...

# %%
#1p loss
compareExpression2('CXCL11',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')

#11q loss
compareExpression2('CXCL11',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')

#17q gain
compareExpression2('CXCL11',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')

#All three SCAs
compareExpression2('CXCL11',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=9.818e-02 stat=1.683e+00
# No Loss: median = 0.16799999999999998, mean = 0.214515, 95% CI = (-0.07374299417648883, 0.5027729941764889)
# Loss: median = -0.3919, mean = -0.3004133333333333, 95% CI = (-0.910602229259382, 0.3097755625927153)
# No Loss v.s. Loss: t-test independent samples, P_val=7.755e-01 stat=-2.866e-01
# No Loss: median = 0.09484999999999999, mean = 0.03475714285714284, 95% CI = (-0.3913197286350933, 0.46083401434937893)
# Loss: median = 0.0915, mean = 0.11485925925925927, 95% CI = (-0.22553903173708972, 0.45525755025560827)
# No Gain v.s. Gain: t-test independent samples, P_val=7.324e-01 stat=-3.438e-01
# No Gain: median = 0.1234, mean = 0.028613793103448287, 95% CI = (-0.3516114697842297, 0.4088390559911263)
# Gain: median = 0.0789, mean = 0.1247923076923077, 95% CI = (-0.2694871915302072, 0.5190718069148226)
# No SCA v.s. SCA: t-test independent samples, P_val=3.880e-01 stat=8.704e-01
# ...

# %%
#1p loss
compareExpression2('AGTR1',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')

#11q loss
compareExpression2('AGTR1',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')

#17q gain
compareExpression2('AGTR1',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')

#All three SCAs
compareExpression2('AGTR1',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=8.871e-01 stat=-1.426e-01
# No Loss: median = -0.3166, mean = -0.07173749999999998, 95% CI = (-0.3779321902166741, 0.23445719021667413)
# Loss: median = -0.3574, mean = -0.02627333333333334, 95% CI = (-0.6414761589976563, 0.5889294923309896)
# No Loss v.s. Loss: t-test independent samples, P_val=1.790e-01 stat=1.362e+00
# No Loss: median = -0.3166, mean = 0.12733214285714284, 95% CI = (-0.2951512596222268, 0.5498155453365126)
# Loss: median = -0.5975, mean = -0.2529222222222222, 95% CI = (-0.5972894621180127, 0.09144501767356833)
# No Gain v.s. Gain: t-test independent samples, P_val=2.349e-01 stat=1.202e+00
# No Gain: median = -0.3197, mean = 0.10007241379310342, 95% CI = (-0.34887153643865143, 0.5490163640248582)
# Gain: median = -0.48945000000000005, mean = -0.2371423076923077, 95% CI = (-0.5311248323851385, 0.05684021700052305)
# No SCA v.s. SCA: t-test independent samples, P_val=5.656e-01 stat=5.781e-01
# ...

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
#1p loss
ch1p_non_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch1p_non_loss_samples)))
ch1p_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch1p_loss_samples)))
compareExpression2('CXCL10',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('CXCL11',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('AGTR1',[ch1p_non_loss_samples,ch1p_loss_samples],'Chromosome 1p loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=5.432e-01 stat=-6.138e-01
# No Loss: median = 0.2945, mean = 0.34485625, 95% CI = (0.04969753364974855, 0.6400149663502515)
# Loss: median = 0.4351, mean = 0.5696666666666668, 95% CI = (0.07640758158909267, 1.062925751744241)
# No Loss v.s. Loss: t-test independent samples, P_val=3.700e-01 stat=-9.078e-01
# No Loss: median = 0.23345, mean = 0.26665937500000003, 95% CI = (-0.03140094694061918, 0.5647196969406192)
# Loss: median = 0.70345, mean = 0.6108833333333333, 95% CI = (-0.030583181075199084, 1.2523498477418658)
# No Loss v.s. Loss: t-test independent samples, P_val=3.354e-01 stat=-9.764e-01
# No Loss: median = -0.391, mean = -0.12172500000000006, 95% CI = (-0.48085785071191944, 0.2374078507119193)
# Loss: median = -0.13884999999999997, mean = 0.38315000000000005, 95% CI = (-1.0179427248385613, 1.7842427248385615)

# %%
#11q loss
ch11q_non_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch11q_non_loss_samples)))
ch11q_loss_samples = list(set(MYCN_groups[0]).intersection(set(ch11q_loss_samples)))
compareExpression2('CXCL10',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('CXCL11',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
compareExpression2('AGTR1',[ch11q_non_loss_samples,ch11q_loss_samples],'Chromosome 11q loss',['No Loss','Loss'],'t-test_ind')
# Out:
# No Loss v.s. Loss: t-test independent samples, P_val=6.910e-01 stat=-4.007e-01
# No Loss: median = 0.3625, mean = 0.30592307692307696, 95% CI = (-0.12839359708605486, 0.7402397509322087)
# Loss: median = 0.3721, mean = 0.4190560000000001, 95% CI = (0.09028337276010312, 0.7478286272398971)
# No Loss v.s. Loss: t-test independent samples, P_val=1.980e-01 stat=1.312e+00
# No Loss: median = 0.5037, mean = 0.5694923076923076, 95% CI = (0.17217994773087997, 0.9668046676537353)
# Loss: median = 0.1434, mean = 0.19180000000000003, 95% CI = (-0.1581070873403037, 0.5417070873403038)
# No Loss v.s. Loss: t-test independent samples, P_val=1.744e-01 stat=1.386e+00
# No Loss: median = -0.3197, mean = 0.3156538461538462, 95% CI = (-0.4842160014222562, 1.1155236937299486)
# Loss: median = -0.5975, mean = -0.22799200000000003, 95% CI = (-0.5982760230787321, 0.142292023078732)

# %%
#17q gain
ch17q_non_gain_samples = list(set(MYCN_groups[0]).intersection(set(ch17q_non_gain_samples)))
ch17q_gain_samples = list(set(MYCN_groups[0]).intersection(set(ch17q_gain_samples)))
compareExpression2('CXCL10',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('CXCL11',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
compareExpression2('AGTR1',[ch17q_non_gain_samples,ch17q_gain_samples],'Chromosome 17q gain',['No Gain','Gain'],'t-test_ind')
# Out:
# No Gain v.s. Gain: t-test independent samples, P_val=2.113e-01 stat=-1.273e+00
# No Gain: median = 0.2265, mean = 0.21323157894736847, 95% CI = (-0.12605068725116766, 0.5525138451459046)
# Gain: median = 0.4956, mean = 0.5474736842105263, 95% CI = (0.16034022909505852, 0.9346071393259942)
# No Gain v.s. Gain: t-test independent samples, P_val=6.195e-01 stat=5.008e-01
# No Gain: median = 0.4268, mean = 0.3908052631578947, 95% CI = (0.08084034257447725, 0.7007701837413122)
# Gain: median = 0.1926, mean = 0.2512157894736842, 95% CI = (-0.19861716481373504, 0.7010487437611035)
# No Gain v.s. Gain: t-test independent samples, P_val=2.247e-01 stat=1.235e+00
# No Gain: median = -0.3197, mean = 0.1891421052631579, 95% CI = (-0.45980127149585326, 0.838085482022169)
# Gain: median = -0.6211, mean = -0.2731578947368421, 95% CI = (-0.6149742835446746, 0.06865849407099045)

# %%
#All three SCAs
non_sca_samples = list(set(MYCN_groups[0]).intersection(set(non_sca_samples)))
sca_samples = list(set(MYCN_groups[0]).intersection(set(sca_samples)))
compareExpression2('CXCL10',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('CXCL11',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
compareExpression2('AGTR1',[non_sca_samples,sca_samples],'SCA',['No SCA','SCA'],'t-test_ind')
# Out:
# No SCA v.s. SCA: t-test independent samples, P_val=5.345e-01 stat=-6.272e-01
# No SCA: median = 0.2945, mean = 0.21818750000000003, 95% CI = (-0.40612146837741353, 0.8424964683774137)
# SCA: median = 0.37334999999999996, mean = 0.42359666666666673, 95% CI = (0.13621556473241714, 0.7109777686009163)
# No SCA v.s. SCA: t-test independent samples, P_val=4.212e-01 stat=8.136e-01
# No SCA: median = 0.46525000000000005, mean = 0.53935, 95% CI = (0.016544576697666402, 1.0621554233023336)
# SCA: median = 0.16799999999999998, mean = 0.26278666666666667, 95% CI = (-0.05090747913718663, 0.57648081247052)
# No SCA v.s. SCA: t-test independent samples, P_val=6.220e-01 stat=4.972e-01
# No SCA: median = -0.18889999999999998, mean = 0.14131249999999998, 95% CI = (-0.677680922285672, 0.9603059222856719)
# SCA: median = -0.52925, mean = -0.09089333333333331, 95% CI = (-0.5101341209359462, 0.3283474542692796)

# %% [markdown]
# # TP53/PTPN6/NTRK1 Pathway Analysis

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]
compareExpression2('CXCL10',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=3.670e-02 stat=-2.100e+00
# Activated: median = -0.4937, mean = -0.4609105263157895, 95% CI = (-0.7587109333507244, -0.16311011928085462)
# Not activated: median = -0.0091, mean = 0.03807304347826089, 95% CI = (-0.09332797870022062, 0.1694740656567424)

# %%
#TP53
geneScatter('CXCL10','TP53')

#PTPN6
geneScatter('CXCL10','PTPN6')

#NTRK1
geneScatter('CXCL10','NTRK1')
# Out:
# Pearson correlation coefficient = -0.18777793195874537
# p-value = 0.00293291995541907
# Pearson correlation coefficient = 0.6286799160396798
# p-value = 8.506275751499528e-29
# Pearson correlation coefficient = 0.16422174624690075
# p-value = 0.009432027617841046

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]
compareExpression2('CXCL11',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=1.175e-02 stat=-2.538e+00
# Activated: median = -0.5808, mean = -0.5547578947368421, 95% CI = (-0.8132721117183099, -0.29624367775537425)
# Not activated: median = -0.02305, mean = 0.04582608695652174, 95% CI = (-0.0855708461500321, 0.17722302006307558)

# %%
#TP53
geneScatter('CXCL11','TP53')

#PTPN6
geneScatter('CXCL11','PTPN6')

#NTRK1
geneScatter('CXCL11','NTRK1')
# Out:
# Pearson correlation coefficient = -0.17315173708368245
# p-value = 0.006157737423834279
# Pearson correlation coefficient = 0.4940252446671965
# p-value = 9.983336752265291e-17
# Pearson correlation coefficient = 0.11157856222145185
# p-value = 0.07886461834684022

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

data = [activated_samples,nonactivated_samples]
compareExpression2('AGTR1',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=7.619e-01 stat=-3.033e-01
# Activated: median = -0.0717, mean = -0.06713157894736846, 95% CI = (-0.3727791622186347, 0.23851600432389783)
# Not activated: median = -0.2713, mean = 0.005546086956521744, 95% CI = (-0.12692009688632852, 0.13801227079937203)

# %%
#TP53
geneScatter('AGTR1','TP53')

#PTPN6
geneScatter('AGTR1','PTPN6')

#NTRK1
geneScatter('AGTR1','NTRK1')
# Out:
# Pearson correlation coefficient = 0.058995431373126336
# p-value = 0.3538975882451333
# Pearson correlation coefficient = -0.008002407117434059
# p-value = 0.9000149338627066
# Pearson correlation coefficient = 0.09120722614505952
# p-value = 0.15129377719552226

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
#using z-score cutoff of 0.5 for activated pathway
activated_samples = []

for sample in z_scores.iloc[:,2:].columns:
    tp53_score = z_scores.loc[z_scores['Hugo_Symbol']=='TP53'][sample].values[0]
    ptpn6_score = z_scores.loc[z_scores['Hugo_Symbol']=='PTPN6'][sample].values[0]
    ntrk1_score = z_scores.loc[z_scores['Hugo_Symbol']=='NTRK1'][sample].values[0]
    if(tp53_score < -0.5 and ptpn6_score < -0.5 and ntrk1_score > 0.5):
        activated_samples.append(sample)

nonactivated_samples = list(set(z_scores.iloc[:,2:].columns) - set(activated_samples))

activated_samples = list(set(MYCN_groups[0]).intersection(set(activated_samples)))
nonactivated_samples = list(set(MYCN_groups[0]).intersection(set(nonactivated_samples)))

data = [activated_samples,nonactivated_samples]
compareExpression2('CXCL10',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('CXCL11',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
compareExpression2('AGTR1',data,'TrkA Pathway Activation',['Activated',"Not activated"],'t-test_ind')
# Out:
# Activated v.s. Not activated: t-test independent samples, P_val=2.588e-03 stat=-3.057e+00
# Activated: median = -0.4937, mean = -0.4609105263157895, 95% CI = (-0.7587109333507245, -0.16311011928085456)
# Not activated: median = 0.0701, mean = 0.23494423076923077, 95% CI = (0.08374834171647919, 0.3861401198219824)
# Activated v.s. Not activated: t-test independent samples, P_val=1.093e-03 stat=-3.321e+00
# Activated: median = -0.5808, mean = -0.5547578947368421, 95% CI = (-0.8132721117183099, -0.29624367775537425)
# Not activated: median = 0.09275, mean = 0.2082192307692308, 95% CI = (0.054526609281714516, 0.36191185225674705)
# Activated v.s. Not activated: t-test independent samples, P_val=6.339e-01 stat=-4.771e-01
# Activated: median = -0.0717, mean = -0.06713157894736846, 95% CI = (-0.3727791622186347, 0.23851600432389783)
# Not activated: median = -0.27349999999999997, mean = 0.06339423076923079, 95% CI = (-0.11967709868705198, 0.24646556022551355)

# %%
#TP53
geneScatter('CXCL10','TP53',z_scores=nonamplified_MYCN_z_scores)
geneScatter('CXCL11','TP53',z_scores=nonamplified_MYCN_z_scores)
geneScatter('AGTR1','TP53',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = 0.026777834687329277
# p-value = 0.7250168136866495
# Pearson correlation coefficient = 0.02889258675693443
# p-value = 0.7042771445545998
# Pearson correlation coefficient = 0.22767627346287278
# p-value = 0.0024440149904370262

# %%
#PTPN6
geneScatter('CXCL10','PTPN6',z_scores=nonamplified_MYCN_z_scores)
geneScatter('CXCL11','PTPN6',z_scores=nonamplified_MYCN_z_scores)
geneScatter('AGTR1','PTPN6',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = 0.5536172169009301
# p-value = 1.925682313593396e-15
# Pearson correlation coefficient = 0.4331677962995146
# p-value = 2.132980875532829e-09
# Pearson correlation coefficient = -0.06494325619386469
# p-value = 0.39318059927723426

# %%
#NTRK1
geneScatter('CXCL10','NTRK1',z_scores=nonamplified_MYCN_z_scores)
geneScatter('CXCL11','NTRK1',z_scores=nonamplified_MYCN_z_scores)
geneScatter('AGTR1','NTRK1',z_scores=nonamplified_MYCN_z_scores)
# Out:
# Pearson correlation coefficient = -0.06532596832803891
# p-value = 0.39039230513850093
# Pearson correlation coefficient = -0.05626509338636465
# p-value = 0.45956140697257036
# Pearson correlation coefficient = 0.01585966727547582
# p-value = 0.8349843998211327

# %% [markdown]
# # Diagnosis Age Analysis

# %%
Age_groups = stratifyNumericalPatientData('Diagnosis Age (days)', 540) #540 days ~ 18 months
compareExpression2('CXCL10', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('CXCL11', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('AGTR1', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
# Out:
# <18mo v.s. >=18mo: t-test independent samples, P_val=3.434e-02 stat=-2.128e+00
# <18mo: median = -0.396, mean = -0.35579677419354844, 95% CI = (-0.5712600679802344, -0.14033348040686242)
# >=18mo: median = 0.015300000000000001, mean = 0.05059266055045869, 95% CI = (-0.08704227317739588, 0.18822759427831326)
# <18mo v.s. >=18mo: t-test independent samples, P_val=4.132e-03 stat=-2.895e+00
# <18mo: median = -0.4763, mean = -0.4803903225806451, 95% CI = (-0.6890973895687202, -0.27168325559257)
# >=18mo: median = -0.0033499999999999997, mean = 0.06831055045871559, 95% CI = (-0.0684380030404777, 0.20505910395790888)
# <18mo v.s. >=18mo: t-test independent samples, P_val=5.037e-02 stat=1.966e+00
# <18mo: median = -0.0979, mean = 0.32923548387096774, 95% CI = (-0.09741990632000264, 0.7558908740619381)
# >=18mo: median = -0.2958, mean = -0.04681743119266056, 95% CI = (-0.17460453075700322, 0.08096966837168208)

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
Age_groups = stratifyNumericalPatientData('Diagnosis Age (days)', 540) #540 days ~ 18 months
Age_groups[0] = list(set(MYCN_groups[0]).intersection(set(Age_groups[0])))
Age_groups[1] = list(set(MYCN_groups[0]).intersection(set(Age_groups[1])))
compareExpression2('CXCL10', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('CXCL11', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
compareExpression2('AGTR1', Age_groups,'Diagnosis Age',['<18mo','>=18mo'],'t-test_ind')
# Out:
# <18mo v.s. >=18mo: t-test independent samples, P_val=3.031e-03 stat=-3.007e+00
# <18mo: median = -0.3958, mean = -0.3187517241379311, 95% CI = (-0.5424443000769609, -0.09505914819890138)
# >=18mo: median = 0.1464, mean = 0.25436849315068494, 95% CI = (0.0941497119746443, 0.4145872743267256)
# <18mo v.s. >=18mo: t-test independent samples, P_val=1.938e-04 stat=-3.809e+00
# <18mo: median = -0.4763, mean = -0.4796862068965518, 95% CI = (-0.7028349521120982, -0.2565374616810053)
# >=18mo: median = 0.1384, mean = 0.24556643835616437, 95% CI = (0.08547419032457004, 0.4056586863877587)
# <18mo v.s. >=18mo: t-test independent samples, P_val=8.715e-02 stat=1.720e+00
# <18mo: median = -0.0717, mean = 0.37517931034482765, 95% CI = (-0.07647925994127969, 0.826837880630935)
# >=18mo: median = -0.32205, mean = -0.015521917808219187, 95% CI = (-0.19257357281015453, 0.16152973719371616)

# %% [markdown]
# # Tumor Sample Histology

# %%
histology_groups = stratifyCategoricalPatientData('Tumor Sample Histology','Unfavorable','Favorable')
compareExpression2('CXCL10',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('CXCL11',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('AGTR1',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
# Out:
# Unfavorable v.s. Favorable: t-test independent samples, P_val=2.004e-01 stat=1.284e+00
# Unfavorable: median = -0.0078, mean = 0.009090710382513648, 95% CI = (-0.14092954689251364, 0.15911096765754096)
# Favorable: median = -0.3427, mean = -0.21987297297297295, 95% CI = (-0.4484987687684827, 0.008752822822536782)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=5.785e-02 stat=1.907e+00
# Unfavorable: median = -0.013999999999999999, mean = 0.02228142076502733, 95% CI = (-0.12824169820436715, 0.17280453973442178)
# Favorable: median = -0.3939, mean = -0.31919459459459465, 95% CI = (-0.5515307361531786, -0.08685845303601072)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=8.043e-03 stat=-2.675e+00
# Unfavorable: median = -0.3165, mean = -0.10006448087431695, 95% CI = (-0.23189574001032126, 0.03176677826168735)
# Favorable: median = -0.0704, mean = 0.3656081081081082, 95% CI = (-0.024125025239595366, 0.7553412414558117)

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
histology_groups = stratifyCategoricalPatientData('Tumor Sample Histology','Unfavorable','Favorable')
histology_groups[0] = list(set(MYCN_groups[0]).intersection(set(histology_groups[0])))
histology_groups[1] = list(set(MYCN_groups[0]).intersection(set(histology_groups[1])))
compareExpression2('CXCL10',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('CXCL11',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
compareExpression2('AGTR1',[histology_groups[0],histology_groups[1]],'Tumor Sample Histology',['Unfavorable','Favorable'], 't-test_ind')
# Out:
# Unfavorable v.s. Favorable: t-test independent samples, P_val=3.399e-03 stat=2.974e+00
# Unfavorable: median = 0.19519999999999998, mean = 0.2858967213114754, 95% CI = (0.11613701084525274, 0.4556564317776981)
# Favorable: median = -0.3427, mean = -0.21987297297297295, 95% CI = (-0.4484987687684827, 0.008752822822536782)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=1.232e-03 stat=3.291e+00
# Unfavorable: median = 0.2502, mean = 0.25186721311475413, 95% CI = (0.07852565403556075, 0.4252087721939475)
# Favorable: median = -0.3939, mean = -0.31919459459459465, 95% CI = (-0.5515307361531786, -0.08685845303601072)
# Unfavorable v.s. Favorable: t-test independent samples, P_val=4.498e-02 stat=-2.021e+00
# Unfavorable: median = -0.32035, mean = -0.04624508196721314, 95% CI = (-0.23189285446394442, 0.13940269052951815)
# Favorable: median = -0.0704, mean = 0.3656081081081082, 95% CI = (-0.024125025239595366, 0.7553412414558117)

# %% [markdown]
# # Neoplasm Histologic Grade Analysis

# %%
histologic_grade_groups = stratifyCategoricalSampleData('Neoplasm Histologic Grade','Undifferentiated or Poorly Differentiated','Differentiating')
compareExpression2('CXCL10',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('CXCL11',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('AGTR1',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
# Out:
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=5.451e-01 stat=-6.063e-01
# Undifferentiated: median = -0.2092, mean = -0.07754941176470588, 95% CI = (-0.2290275040697931, 0.07392868054038136)
# Differentiating: median = 0.0133, mean = 0.09483846153846157, 95% CI = (-0.25961574385018393, 0.4492926669271071)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=5.571e-01 stat=-5.883e-01
# Undifferentiated: median = -0.15589999999999998, mean = -0.0958694117647059, 95% CI = (-0.24645036183346228, 0.05471153830405048)
# Differentiating: median = 0.094, mean = 0.0713076923076923, 95% CI = (-0.34253859709127554, 0.48515398170666013)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=3.549e-02 stat=-2.119e+00
# Undifferentiated: median = -0.3181, mean = -0.06710117647058825, 95% CI = (-0.21439620655127253, 0.08019385361009604)
# ...

# %% [markdown]
# ### In MYCN nonamplified samples only

# %%
histologic_grade_groups = stratifyCategoricalSampleData('Neoplasm Histologic Grade','Undifferentiated or Poorly Differentiated','Differentiating')
histologic_grade_groups[0] = list(set(MYCN_groups[0]).intersection(set(histologic_grade_groups[0])))
histologic_grade_groups[1] = list(set(MYCN_groups[0]).intersection(set(histologic_grade_groups[1])))
compareExpression2('CXCL10',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('CXCL11',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
compareExpression2('AGTR1',[histologic_grade_groups[0],histologic_grade_groups[1]],'Neoplasm Histologic Grade',['Undifferentiated','Differentiating'], 't-test_ind')
# Out:
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=8.307e-01 stat=2.142e-01
# Undifferentiated: median = 0.0466, mean = 0.15270175438596492, 95% CI = (-0.021115228977946404, 0.3265187377498763)
# Differentiating: median = 0.0133, mean = 0.09483846153846157, 95% CI = (-0.25961574385018393, 0.4492926669271071)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=9.615e-01 stat=4.842e-02
# Undifferentiated: median = -0.02305, mean = 0.08428684210526315, 95% CI = (-0.08653834847034168, 0.25511203268086796)
# Differentiating: median = 0.094, mean = 0.0713076923076923, 95% CI = (-0.34253859709127554, 0.48515398170666013)
# Undifferentiated v.s. Differentiating: t-test independent samples, P_val=1.005e-01 stat=-1.655e+00
# Undifferentiated: median = -0.32725, mean = -0.011214035087719298, 95% CI = (-0.21892715736908105, 0.19649908719364248)
# ...
