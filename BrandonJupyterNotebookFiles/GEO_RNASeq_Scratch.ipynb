# %%
from ipynb.fs.full.GEO_RNASeq_Analysis_Functions import *
# Out:
# /Users/brandonbergs/anaconda2/envs/v3_8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3254: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
geneScatter('WDR47','GSK3B')
# Out:
# Pearson correlation coefficient = 0.3538765527318183
# p-value = 3.882299201928008e-16

# %%
groups = stratifyDataOnGeneExpression('GSK3B',-0.5,0.5)
kaplanmeierEFS(groups, 'Low GSK3B', 'High GSK3B')
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            2.67 0.10      3.29
# p-value = 0.10217550888662369

# %%
groups = stratifyDataOnGeneExpression('WDR47',-0.5,0.5)
kaplanmeierEFS(groups, 'Low WDR47', 'High WDR47')
# Out:
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic      p  -log2(p)
#           72.07 <0.005     55.42
# p-value = 2.0752208202121068e-17
