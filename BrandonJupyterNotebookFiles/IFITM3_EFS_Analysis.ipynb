# %%
from ipynb.fs.full.TARGET_Analysis_Functions import *
from scipy.stats import chi2_contingency

# %% [markdown]
# # IFITM3 Survival Analysis

# %%
EFS_groups = stratifyNumericalPatientData('EFS Time', 1825) #1825 days = 5yrs
compareExpression2('IFITM3', EFS_groups,'EFS Time',['<5yr EFS','>=5yr EFS'],'t-test_ind')
# Out:
# <5yr EFS v.s. >=5yr EFS: t-test independent samples, P_val=3.173e-01 stat=1.002e+00
# <5yr EFS: median = 0.1481, mean = 0.04532327044025158, 95% CI = (-0.11642888202120752, 0.2070754229017107)
# >=5yr EFS: median = -0.0088, mean = -0.08858295454545456, 95% CI = (-0.2847540208636056, 0.10758811177269642)

# %%
#Compare Low, Intermediate, and High IFITM3 expression
IFITM3_groups = stratifyDataOnGeneExpression2('IFITM3',-0.5,0.5)
compareEFS2(IFITM3_groups, 'EFS stratified by IFITM3 expression', ['Low','Intermediate','High'], 't-test_ind')
# Out:
# Low v.s. Intermediate: t-test independent samples, P_val=1.032e-01 stat=-1.639e+00
# Intermediate v.s. High: t-test independent samples, P_val=1.668e-02 stat=2.417e+00
# Low v.s. High: t-test independent samples, P_val=5.003e-01 stat=6.757e-01
# Low: median = 610.0, mean = 1428.2328767123288, 95% CI = (1094.8784769638505, 1761.587276460807)
# Intermediate: median = 1017.5, mean = 1823.938775510204, 95% CI = (1499.594038169716, 2148.283512850692)
# High: median = 665.5, mean = 1279.5, 95% CI = (1003.3952276358932, 1555.6047723641068)

# %%
kaplanmeierEFS2(IFITM3_groups,'EFS stratified by IFITM3 expression',['Low','Intermediate','High'])
# Out:
# Log Rank Test between Low and Intermediate
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.88 0.17      2.56
# Log Rank Test between Low and High
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.16 0.69      0.54
# Log Rank Test between Intermediate and High
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            3.90 0.05      4.37

# %%
#Compare high IFITM3 samples vs remaining samples
IFITM3_groups = stratifyDataOnGeneExpression('IFITM3',0.5,0.5)
compareEFS2(IFITM3_groups, 'EFS stratified by IFITM3 expression', ['Remaining samples', 'High IFITM3 samples'], 't-test_ind')
# Out:
# Remaining samples v.s. High IFITM3 samples: t-test independent samples, P_val=6.575e-02 stat=1.848e+00
# Remaining samples: median = 787.0, mean = 1655.0116959064328, 95% CI = (1419.72829365797, 1890.2950981548956)
# High IFITM3 samples: median = 665.5, mean = 1279.5, 95% CI = (1003.3952276358932, 1555.6047723641068)

# %%
kaplanmeierEFS(IFITM3_groups, 'Remaining samples', 'High IFITM3 samples')

# %%
#Compare low IFITM3 samples vs remaining samples
IFITM3_groups = stratifyDataOnGeneExpression('IFITM3',-0.5,-0.5)
compareEFS2(IFITM3_groups, 'EFS stratified by IFITM3 expression', ['Low IFITM3 samples', 'Remaining samples'], 't-test_ind')
# Out:
# Low IFITM3 samples v.s. Remaining samples: t-test independent samples, P_val=4.456e-01 stat=-7.640e-01
# Low IFITM3 samples: median = 610.0, mean = 1428.2328767123288, 95% CI = (1094.8784769638505, 1761.587276460807)
# Remaining samples: median = 798.5, mean = 1586.1379310344828, 95% CI = (1364.156458398975, 1808.1194036699906)

# %%
kaplanmeierEFS(IFITM3_groups, 'Low IFITM3 samples', 'Remaining samples')
