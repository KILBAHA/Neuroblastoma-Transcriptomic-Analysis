# %% [markdown]
# # Differential Gene Expression Analysis

# %% [markdown]
# ## Import Z scores and Format

# %%
### Read in z_scores and format ###
z_scores = read.csv("data_RNA_Seq_mRNA_median_all_sample_Zscores.txt", sep = "\t", stringsAsFactors = FALSE, header = TRUE)

map = z_scores[,c(1,2)]

inst_names = colnames(z_scores)[3:length(colnames(z_scores))]

z_scores = z_scores[,-2]
z_scores = as.data.frame(t(z_scores), stringsAsFactors = FALSE)
names(z_scores) = map[,1]
z_scores = z_scores[-1,]

z_scores = as.data.frame(apply(z_scores, 2, as.numeric))

name_fix = c()
for(name in inst_names){name_fix = c(name_fix,substr(name,11,nchar(name)-3))}


row.names(z_scores) = name_fix

# %%
z_scores[1:5,1:5]
# Out:
#        A1BG    A1BG-AS A1CF    A2LD1   A2M
# PAAPFA -1.3428 -1.6542 -0.9681 -1.5144  0.9390
# PACLJN -0.5008  1.2776 -1.1983  1.2333  0.2163
# PACPJG -0.2098 -1.6542 -1.1983  0.3050 -0.4804
# PACRYY -1.3428  0.3708 -1.1983 -1.5144 -0.2457
# PACRZM  0.5693 -0.5274 -0.5943  0.5219 -0.5965

# %% [markdown]
# ## Import Clinical data and Format

# %%
patient = as.data.frame(read.csv("data_clinical_patient.txt", sep = "\t", stringsAsFactors = FALSE, header = TRUE, skip = 4))
p_nam = patient[,1]

p_nam_fix = c()
for(name in p_nam){p_nam_fix = c(p_nam_fix,substr(name,11,nchar(name)))}

patient = patient[,2:ncol(patient)]

row.names(patient) = p_nam_fix

# %%
head(patient)
# Out:
#        PROTOCOL           ICDO  SNOMED
# PALPKZ ANBL00B1           C38.2
# PASFWL ANBL00B1, AEPI07N1 C64.9
# PAURYJ ANBL00B1           C64.9
# PARVHG ANBL00B1, ANBL0532 C74.9
# PALNMX ANBL00B1, A3973    C76.2 999
# PAMZSH ANBL00B1, P9641    C76.1
#        ICDO_SNOMED_DESCRIPTION
# PALPKZ Posterior mediastinum
# PASFWL Kidney, NOS Renal, NOS Kidney parenchyma
# PAURYJ Kidney, NOS Renal, NOS Kidney parenchyma
# PARVHG Adrenal gland, NOS Suprarenal gland Adrenal, NOS
# PALNMX Abdomen, NOS Abdominal wall, NOS Intra-abdominal site, NOS
# PAMZSH Thorax, NOS Axilla, NOS Chest, NOS Chest wall, NOS Intrathoracic site, NOS Thoracic wall, NOS Infraclavicular region, NOS Scapular region, NOS
#        AGE_IN_DAYS AGE YEAR_OF_DIAGNOSIS INSS_STAGE TUMOR_SAMPLE_HISTOLOGY
# PALPKZ 1157        4   2002              Stage 4    Unfavorable
# PASFWL  184        1   2008              Stage 2b   Favorable
# PAURYJ   10        1   2012              Stage 4s   Favorable
# PARVHG  730        2   2008              Stage 4    Unknown
# PALNMX 1607        5   2002              Stage 4    Unfavorable
# PAMZSH  315        1   2004              Stage 1    Favorable
#        DIAGNOSIS     ... FIRST_EVENT OS_STATUS  OS_DAYS OS_MONTHS
# PALPKZ Neuroblastoma ... Progression 1:DECEASED 2103     70
# PASFWL Neuroblastoma ... Censored    0:LIVING   2449     81
# PAURYJ Neuroblastoma ... Censored    0:LIVING   1294     43
# PARVHG Neuroblastoma ... Censored    0:LIVING   1913     63
# PALNMX Neuroblastoma ... Censored    0:LIVING   4679    154
# PAMZSH Neuroblastoma ... Censored    0:LIVING   3334    110
#        LAST_FOLLOWUP_YEAR PERCENTAGE_NECROSIS PERCENT_TUMOR_VS_STROMA
# PALPKZ 2008
# PASFWL 2015
# PAURYJ 2015
# PARVHG 2013
# PALNMX 2015
# PAMZSH 2013
#        PERCENT_TUMOR_CELLS_RELAPSE RELAPSE_PERCENT_NECROSIS
# PALPKZ                             NA
# PASFWL                             NA
# PAURYJ                             NA
# PARVHG                             NA
# PALNMX                             NA
# PAMZSH                             NA
#        RELAPSE_PERCENT_STROMA
# PALPKZ
# PASFWL
# PAURYJ
# PARVHG
# PALNMX
# PAMZSH

# %% [markdown]
# ## Isolate Status and Merge

# %%
status = data.frame(patient[,"OS_STATUS"])
colnames(status) = "STATUS"
rownames(status) = p_nam_fix

mg = merge.data.frame(status,z_scores, by="row.names")

# %%
mg[1:5,1:5]
# Out:
#   Row.names STATUS     A1BG    A1BG-AS A1CF
# 1 PAAPFA    1:DECEASED -1.3428 -1.6542 -0.9681
# 2 PACLJN    0:LIVING   -0.5008  1.2776 -1.1983
# 3 PACPJG               -0.2098 -1.6542 -1.1983
# 4 PACRYY    0:LIVING   -1.3428  0.3708 -1.1983
# 5 PACRZM    1:DECEASED  0.5693 -0.5274 -0.5943

# %% [markdown]
# ## Find DEG between status groups

# %%
srv = mg[mg$STATUS == "0:LIVING",]
dec = mg[mg$STATUS == "1:DECEASED",]

get_mean = function(dat){ #finds the mean z score for each attribute in a dataframe
  atribs = colnames(dat)[colnames(dat)!= "Row.names" & colnames(dat)!= "STATUS"]
  ret = c()
  for(atrib in atribs){
    mea = mean(dat[,atrib])
    ret = cbind(ret, mea)
  }
  
  ret = as.data.frame(ret)
  colnames(ret) = atribs
  return(ret)
}

srv_mean = get_mean(srv)
dec_mean = get_mean(dec)

# %% [markdown]
# Note: Certain known prognostic markers do not show a difference in expression in this dataset.

# %%
## calculate the absolute difference in mean between both groups and threshold based on significance
get_deg = function(d1, d2, thresh=0.5){
  ab = abs(d1-d2)
  sig = apply(ab,2, function(imp){imp > thresh})
  deg = ab[,sig]
  return(deg)
}

deg = get_deg(srv_mean, dec_mean)

# %% [markdown]
# # List of differentially expressed genes
#
# note: some of the most important prognostic markers (MYC) are absent from this list

# %%
colnames(deg)
# Out:
#   [1] "ABCA5"        "ABCC10"       "ABCG4"        "ABLIM3"       "ACTL6B"
#   [6] "ACVR2A"       "ADCY1"        "ADRBK2"       "AGPAT4"       "AGPAT6"
#  [11] "AHI1"         "AKIRIN2"      "AKR1C1"       "AKR1C2"       "ALCAM"
#  [16] "ALDH1L2"      "ALDH3A2"      "ALG9"         "ALS2"         "AMIGO2"
#  [21] "AMPH"         "ANK3"         "ANKFN1"       "ANKFY1"       "ANKRA2"
#  [26] "ANKRD12"      "ANKRD13C"     "ANKRD6"       "ANO4"         "AP2B1"
#  [31] "AP4M1"        "APC"          "ARHGAP21"     "ARHGAP23"     "ARHGAP28"
#  [36] "ARHGEF10L"    "ARHGEF12"     "ARMC2"        "ARRB1"        "ARSF"
#  [41] "ASF1A"        "ASH2L"        "ASXL3"        "ATF2"         "ATF7"
#  [46] "ATP9A"        "ATPAF2"       "ATXN1"        "ATXN7L1"      "AUTS2"
#  [51] "B3GALT1"      "B3GAT1"       "BAIAP2"       "BAZ2B"        "BBS9"
#  [56] "BEND4"        "BIRC2"        "BMF"          "BOLA2"        "BPHL"
#  [61] "BTBD3"        "BTBD8"        "BTBD9"        "C11orf63"     "C17orf107"
#  [66] "C17orf42"     "C17orf68"     "C20orf194"    "C22orf9"      "C3orf25"
#  [71] "C5orf13"      "C5orf36"      "C5orf4"       "C5orf42"      "C6orf124"
#  [76] "C6orf136"     "C6orf168"     "C6orf174"     "C6orf35"      "C7orf41"
#  [81] "C7orf60"      "C9orf72"      "CACNA2D3"     "CACNB1"       "CACNB3"
#  [86] "CACNB4"       "CACNG3"       "CADM1"        "CADM3"        "CADM4"
#  [91] "CALCOCO1"     "CALM2"        "CAMK2B"       "CAMK2G"       "CAMTA1"
#  [96] "CAPS2"        "CASD1"        "CCBE1"        "CCDC112"      "CCDC132"
# [101] "CCDC23"       "CCDC88A"      "CD163L1"      "CD200"        "CDH10"
# [106] "CDK5R1"       "CDRT4"        "CGNL1"        "CHD5"         "CHRNE"
# [111] "CLASP1"       "CLIP2"        "CLTCL1"       "CLVS1"        "CNR1"
# [116] "CNTFR"        "COL4A3BP"     "COQ5"         "CPEB3"        "CRCP"
# [121] "CREG2"        "CROT"         "CSPG4P5"      "CSRNP2"       "CSRNP3"
# [126] "CTNND2"       "DAPK1"        "DCC"          "DDC"          "DDX11"
# [131] "DDX12"        "DENND1B"      "DENND2A"      "DENND5B"      "DFNA5"
# [136] "DGKB"         "DIXDC1"       "DLC1"         "DLG2"         "DOC2B"
# [141] "DOCK4"        "DOPEY1"       "DPH1"         "DPYSL3"       "DRD2"
# [146] "DUSP16"       "DUXAP10"      "DYNC1I2"      "DYRK3"        "EBF1"
# [151] "ECEL1"        "EIF2C4"       "EIF3CL"       "ELAVL4"       "ELOVL4"
# [156] "EPB41L4A"     "EPB41L4B"     "EPC1"         "EPHA5"        "EPN2"
# [161] "ERC2"         "EXOC4"        "FAM115A"      "FAM124A"      "FAM126B"
# [166] "FAM131B"      "FAM134B"      "FAM135A"      "FAM164A"      "FAM18B1"
# [171] "FAM18B2"      "FAM36A"       "FAM5B"        "FAM63A"       "FAM63B"
# [176] "FAR2"         "FARP2"        "FBXL20"       "FBXO30"       "FBXO42"
# [181] "FBXO9"        "FCHO2"        "FER"          "FGD6"         "FIGNL2"
# [186] "FLCN"         "FLJ22536"     "FLJ30838"     "FLJ35390"     "FLJ35946"
# [191] "FLJ39632"     "FLJ39739"     "FLJ41327"     "FNBP1L"       "FRMD3"
# [196] "FRS3"         "FYN"          "FZD3"         "GABBR1"       "GAP43"
# [201] "GATS"         "GATSL1"       "GDPD5"        "GFRA3"        "GNAI1"
# [206] "GNG2"         "GPD2"         "GPR85"        "GRIA1"        "GRIA4"
# [211] "GSTA4"        "GSTM2"        "GTF2I"        "GTF2IP1"      "GTF2IRD2"
# [216] "GTF2IRD2P1"   "HACE1"        "HCFC2"        "HDAC5"        "HECW1"
# [221] "HECW2"        "HERPUD2"      "HGSNAT"       "HIVEP2"       "HIVEP3"
# [226] "HMGCLL1"      "HOXC9"        "HS3ST5"       "HSD17B3"      "ICA1L"
# [231] "ICK"          "IGSF3"        "INPP1"        "INPP5F"       "INPP5K"
# [236] "INSRR"        "INTS4"        "JAKMIP2"      "JAZF1"        "JUP"
# [241] "KCNK10"       "KCNK9"        "KCNT1"        "KCTD21"       "KCTD7"
# [246] "KDM4A"        "KIAA0240"     "KIAA0408"     "KIAA0528"     "KIAA1211"
# [251] "KIAA1324L"    "KIAA1549"     "KIAA1715"     "KIAA1841"     "KIAA1908"
# [256] "KIDINS220"    "KIF13A"       "KIF1B"        "KIF3A"        "KIF5A"
# [261] "KIF5C"        "KIFAP3"       "KLC4"         "KLF12"        "KLHL4"
# [266] "KLRAQ1"       "KPNA5"        "KSR1"         "LASS5"        "LMBR1L"
# [271] "LMBRD1"       "LOC100093631" "LOC100127950" "LOC100128288" "LOC100130691"
# [276] "LOC100131199" "LOC100132167" "LOC100132686" "LOC100133616" "LOC100286793"
# [281] "LOC100288346" "LOC100505679" "LOC100506365" "LOC100506727" "LOC100506761"
# [286] "LOC100506870" "LOC100506881" "LOC100507341" "LOC100509093" "LOC100509475"
# [291] "LOC100509844" "LOC100510371" "LOC145783"    "LOC153811"    "LOC158696"
# [296] "LOC283140"    "LOC283177"    "LOC283454"    "LOC283484"    "LOC283683"
# [301] "LOC284023"    "LOC284244"    "LOC286367"    "LOC387647"    "LOC387790"
# [306] "LOC440104"    "LOC440297"    "LOC440434"    "LOC645321"    "LOC648149"
# [311] "LOC728537"    "LOC729177"    "LOC729723"    "LOC730091"    "LONRF2"
# [316] "LRGUK"        "LRRC28"       "LRRC37B"      "LRRC37BP1"    "LRRTM3"
# [321] "LRRTM4"       "MACF1"        "MAP2"         "MAP2K4"       "MAP3K12"
# [326] "MAP4K4"       "MAP6"         "MAP7"         "MAPK12"       "MAPT"
# [331] "MARCH4"       "MARCH6"       "MARCKS"       "MAST2"        "MBD5"
# [336] "MCF2L2"       "MDGA1"        "MED12L"       "MED23"        "MED7"
# [341] "MFSD6"        "MLL5"         "MLLT4"        "MORN4"        "MTSS1"
# [346] "MUC15"        "MYO18A"       "MYO6"         "NAGK"         "NAIP"
# [351] "NAV3"         "NBR1"         "NCALD"        "NCAM1"        "NCOR1"
# [356] "NDUFA4"       "NEO1"         "NEURL4"       "NFU1"         "NIPSNAP3B"
# [361] "NRCAM"        "NRSN1"        "NRXN2"        "NT5C1A"       "NTRK1"
# [366] "NXPH1"        "ODZ3"         "OSBPL9"       "PAAF1"        "PAFAH1B1"
# [371] "PAK1"         "PAK7"         "PAPOLG"       "PBX1"         "PCDH1"
# [376] "PCDHB10"      "PCDHB11"      "PCDHB12"      "PCDHB13"      "PCDHB15"
# [381] "PCDHB16"      "PCDHB18"      "PCDHB4"       "PCDHB9"       "PCDHGC4"
# [386] "PCLO"         "PDE10A"       "PDE4DIP"      "PECR"         "PEX11B"
# [391] "PEX3"         "PGAP3"        "PGM2L1"       "PHIP"         "PHLDB1"
# [396] "PIGL"         "PIK3R1"       "PIP4K2B"      "PKIA"         "PKIB"
# [401] "PLCD4"        "PLCL1"        "PLEKHA8"      "PLEKHG5"      "PLSCR3"
# [406] "PLXNA4"       "PLXNC1"       "PMP22"        "POF1B"        "PPAN"
# [411] "PPIP5K2"      "PPP3CB"       "PRICKLE1"     "PRICKLE2"     "PRKAA2"
# [416] "PRKACB"       "PRPSAP2"      "PSD2"         "PTBP2"        "PTPRD"
# [421] "PTPRF"        "PTPRH"        "PTS"          "PVRL1"        "R3HDM2"
# [426] "RAB27B"       "RAB3B"        "RAB3GAP1"     "RAB5B"        "RABEP1"
# [431] "RAI1"         "RAMP3"        "RAPGEF2"      "RAPGEF5"      "RAPGEF6"
# [436] "RAPH1"        "RBFOX2"       "REEP1"        "REP15"        "RERE"
# [441] "REV3L"        "RFFL"         "RGMB"         "RGS9"         "RHOT1"
# [446] "RHOU"         "RIMS1"        "RND3"         "RNF11"        "RNF146"
# [451] "RNF152"       "RNF165"       "RPAP3"        "RSF1"         "RSPH4A"
# [456] "RUNDC3B"      "RUNX1T1"      "RWDD2A"       "SCAPER"       "SCARA3"
# [461] "SCG2"         "SCML4"        "SCN2A"        "SCN3A"        "SCN3B"
# [466] "SCN7A"        "SCN9A"        "SEC63"        "SEMA6D"       "SENP6"
# [471] "SENP7"        "SEPT7"        "SEPT7P2"      "SERAC1"       "SERINC1"
# [476] "SESTD1"       "SGIP1"        "SGK196"       "SGSM1"        "SH3BP4"
# [481] "SHANK2"       "SHROOM2"      "SIDT2"        "SLC12A1"      "SLC18A2"
# [486] "SLC25A11"     "SLC25A40"     "SLC27A3"      "SLC29A4"      "SLC30A4"
# [491] "SLC35E2"      "SLC35E2B"     "SLC35F5"      "SLC38A2"      "SLC43A2"
# [496] "SLITRK3"      "SLX1A"        "SMCR7"        "SMG6"         "SNAP91"
# [501] "SNAPC4"       "SNX14"        "SOCS7"        "SORBS2"       "SOX4"
# [506] "SOX6"         "SP4"          "SPAG9"        "SPCS2"        "SPTB"
# [511] "SRCIN1"       "SREK1IP1"     "SRR"          "SRRM4"        "SRSF12"
# [516] "SSBP2"        "SSBP3"        "SSH2"         "ST3GAL3"      "ST7"
# [521] "ST7OT3"       "ST8SIA1"      "ST8SIA2"      "STAG3L4"      "STAM2"
# [526] "STARD10"      "STARD3NL"     "STK33"        "STMN1"        "STMN2"
# [531] "STMN4"        "STRADB"       "STX12"        "SULT1A1"      "SULT1A3"
# [536] "SV2B"         "SVOP"         "SYNRG"        "TADA2A"       "TAOK1"
# [541] "TCP11L2"      "TECTA"        "TFAP2B"       "THSD7A"       "TIA1"
# [546] "TMEM106B"     "TMEM107"      "TMEM169"      "TMEM196"      "TMEM44"
# [551] "TMEM63B"      "TOM1L2"       "TOX2"         "TRA2A"        "TRIL"
# [556] "TRIM2"        "TRIM23"       "TRIM36"       "TRIM55"       "TRIM67"
# [561] "TRIP4"        "TRMT6"        "TRNAU1AP"     "TRPV2"        "TSEN54"
# [566] "TTC21B"       "TTLL7"        "UBE2D4"       "UBE2H"        "UBE2Q2P1"
# [571] "UBR2"         "UBR3"         "UBXN2B"       "ULK2"         "URGCP"
# [576] "USP35"        "VANGL2"       "VGLL4"        "VPS26B"       "VPS54"
# [581] "VSTM2A"       "VSTM2L"       "VWDE"         "WDFY2"        "WDR47"
# [586] "WDSUB1"       "WIPI2"        "WNT4"         "WSB1"         "YPEL1"
# [591] "ZBTB20"       "ZBTB4"        "ZC3H6"        "ZCCHC18"      "ZKSCAN3"
# [596] "ZNF187"       "ZNF276"       "ZNF280D"      "ZNF292"       "ZNF362"
# [601] "ZNF436"       "ZNF540"       "ZNF608"       "ZNF624"       "ZNF641"
# [606] "ZNF713"       "ZNF76"        "ZNF804A"      "ZSWIM5"       "ZSWIM7"
# [611] "ZZEF1"
