# %%
from ipynb.fs.full.CovidReceptorExpressionAnalysis_Functions import *
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5c0e85f313f4> in <module>
# ----> 1 from ipynb.fs.full.CovidReceptorExpressionAnalysis_Functions import *
#
# ~/Documents/GitHub/BioinfGroupProject/GSEA_rank_cluster/CovidReceptorExpressionAnalysis_Functions.ipynb in <module>
#      20    "source": [
#      21     "import pandas as pd\n",
# ---> 22     "import numpy as np\n",
#      23     "import matplotlib.pyplot as plt\n",
#      24     "import scipy.stats as st\n",
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_mRNA_median_all_sample_Zscores.txt'

# %%
c1_patients = pd.read_csv('c1.txt',header=None)[0].tolist()
c2_patients = pd.read_csv('c2.txt',header=None)[0].tolist()

for i in range(len(c1)):
    c1_patients[i] = ('TARGET-30-' + c1_patients[i])
for i in range(len(c2)):
    c2_patients[i] = ('TARGET-30-' + c2_patients [i])

c1_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c1_patients)]['Sample Identifier']
c2_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c2_patients)]['Sample Identifier']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e68713cf1a4b> in <module>
# ----> 1 c1_patients = pd.read_csv('c1.txt',header=None)[0].tolist()
#       2 c2_patients = pd.read_csv('c2.txt',header=None)[0].tolist()
#       3
#       4 for i in range(len(c1)):
#       5     c1_patients[i] = ('TARGET-30-' + c1_patients[i])
#
# NameError: name 'pd' is not defined

# %%
compareEFS([c1_samples,c2_samples], 'EFS stratified by GSEA rank clusters', 'c1', 'c2')
# Out:
# c1: median EFS = 682.0, mean EFS = 1361.6470588235295, 95% CI = (1052.2281481521331, 1671.0659694949259)
# c2: median EFS = 751.0, mean EFS = 1607.022346368715, 95% CI = (1381.2081143056084, 1832.8365784318216)
# Ttest_indResult(statistic=-1.1640345946595516, pvalue=0.2455422911316802)

# %%
kaplanmeierEFS([c1_samples,c2_samples], 'c1', 'c2')

# %%
compareExpression('ACE2',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = -0.20675, mean = -0.2128323529411765, 95% CI = (-0.4645714477166347, 0.038906741834281694)
# c2: median = 0.0338, mean = 0.07995801104972373, 95% CI = (-0.061454831017622155, 0.2213708531170696)
# Ttest_indResult(statistic=-2.067885288542731, pvalue=0.0396921629467833)

# %%
compareExpression('TMPRSS2',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = -0.47485, mean = -0.4964058823529412, 95% CI = (-0.6919133612339095, -0.300898403471973)
# c2: median = 0.192, mean = 0.18649613259668504, 95% CI = (0.040564280671270964, 0.3324279845220991)
# Ttest_indResult(statistic=-5.019913113227142, pvalue=9.901509218668074e-07)

# %%
compareExpression('IFITM3',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = 0.0524, mean = -0.015476470588235255, 95% CI = (-0.29628428582288974, 0.2653313446464192)
# c2: median = 0.0543, mean = 0.005819337016574589, 95% CI = (-0.12956876608388065, 0.14120744011702982)
# Ttest_indResult(statistic=-0.14912656875091437, pvalue=0.88157544645931)

# %%
compareExpression('MYCN',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = 0.2415, mean = 0.4192176470588236, 95% CI = (0.14838222841242527, 0.690053065705222)
# c2: median = -0.3736, mean = -0.15749779005524864, 95% CI = (-0.2885074717819629, -0.02648810832853435)
# Ttest_indResult(statistic=4.17863425456416, pvalue=4.0720450327186467e-05)

# %%
compareExpression('NTRK1',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = -1.0732, mean = -0.8110514705882353, 95% CI = (-0.9837755855194839, -0.6383273556569868)
# c2: median = 0.429, mean = 0.30470607734806626, 95% CI = (0.17079677026573184, 0.4386153844304007)
# Ttest_indResult(statistic=-9.004362215568845, pvalue=6.002599599174178e-17)

# %%
compareExpression('PTPN6',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = 0.2504, mean = 0.22694852941176474, 95% CI = (-0.088098331910347, 0.5419953907338765)
# c2: median = -0.1472, mean = -0.08526850828729282, 95% CI = (-0.20737980947215817, 0.03684279289757254)
# Ttest_indResult(statistic=2.20771806541235, pvalue=0.028183478875522503)

# %%
compareExpression('TP53',[c1_samples,c2_samples],'Clusters','c1','c2')
# Out:
# c1: median = 0.7762, mean = 0.6341779411764705, 95% CI = (0.4139514225897334, 0.8544044597632077)
# c2: median = -0.3679, mean = -0.23825745856353592, 95% CI = (-0.3729452928394857, -0.10356962428758615)
# Ttest_indResult(statistic=6.630525274196496, pvalue=2.0901146024621623e-10)
