# %%
from ipynb.fs.full.CovidReceptorExpressionAnalysis_Functions import *

# %%
c1_patients = pd.read_csv('c1.txt',header=None)[0].tolist()
c2_patients = pd.read_csv('allpat.txt',header=None)[0].tolist()

for i in range(len(c1_patients)):
    c1_patients[i] = ('TARGET-30-' + c1_patients[i])
for i in range(len(c2_patients)):
    c2_patients[i] = ('TARGET-30-' + c2_patients [i])

c1_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c1_patients)]['Sample Identifier']
c2_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c2_patients)]['Sample Identifier']

# %%
compareEFS([c1_samples,c2_samples], 'EFS stratified by GSEA rank clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median EFS = 476.0, mean EFS = 1430.3333333333333, 95% CI = (262.3846809238689, 2598.2819857427976)
# Remaining: median EFS = 721.0, mean EFS = 1539.4696356275304, 95% CI = (1354.7937629686828, 1724.145508286378)
# Ttest_indResult(statistic=-0.21562673456510037, pvalue=0.8294517632605616)

# %%
kaplanmeierEFS([c1_samples,c2_samples], 'Cluster', 'Remaining')

# %%
compareExpression('ACE2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 1.527, mean = 1.2696777777777777, 95% CI = (0.7367013477225746, 1.8026542078329808)
# Remaining: median = -0.0694, mean = -8.032128513894826e-07, 95% CI = (-0.12445874585833178, 0.12445713943262901)
# Ttest_indResult(statistic=3.7543146637171314, pvalue=0.00021515369973438658)

# %%
compareExpression('TMPRSS2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 1.7167, mean = 1.6425999999999998, 95% CI = (1.1814767711917737, 2.103723228808226)
# Remaining: median = -0.0537, mean = 8.032128514073175e-07, 95% CI = (-0.12445711284165682, 0.12445871926735964)
# Ttest_indResult(statistic=4.869839832124164, pvalue=1.9574159769991766e-06)

# %%
compareExpression('IFITM2', [c1_samples,c2_samples], 'Clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median = -1.7826, mean = -1.293111111111111, 95% CI = (-2.227411033829589, -0.35881118839263315)
# Remaining: median = -0.0188, mean = 8.032128514073175e-07, 95% CI = (-0.12445700147940347, 0.1244586079051063)
# Ttest_indResult(statistic=-3.743249358076076, pvalue=0.00022433846723709055)

# %%
compareExpression('IFITM3',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -1.5487, mean = -0.9493888888888888, 95% CI = (-1.7669475972021798, -0.13183018057559803)
# Remaining: median = 0.0543, mean = 3.6144578313204443e-06, 95% CI = (-0.12445465649744394, 0.12446188541310657)
# Ttest_indResult(statistic=-2.768321336362929, pvalue=0.006046353164730972)

# %%
compareExpression('MYCN',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 1.137, mean = 0.6612888888888889, 95% CI = (-0.16128158236838364, 1.4838593601461616)
# Remaining: median = -0.2762, mean = -1.2048192771127598e-06, 95% CI = (-0.12445973523620296, 0.12445732559764874)
# Ttest_indResult(statistic=1.9276757097709851, pvalue=0.05500174947138122)

# %%
compareExpression('NTRK1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -1.0843, mean = -0.831, 95% CI = (-1.164020319311944, -0.49797968068805587)
# Remaining: median = 0.1392, mean = 1.2048192771091927e-06, 95% CI = (-0.12445668548141911, 0.12445909511997333)
# Ttest_indResult(statistic=-2.473020127366993, pvalue=0.014047625327886405)

# %%
compareExpression('PTPN6',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.7119, mean = -0.6305444444444444, 95% CI = (-1.0975717352379886, -0.16351715365090014)
# Remaining: median = -0.1149, mean = -4.417670682717061e-06, 95% CI = (-0.12446198867814712, 0.1244531533367817)
# Ttest_indResult(statistic=-1.8689977405995568, pvalue=0.062764981775518)

# %%
compareExpression('TP53',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.3296, mean = 0.49035555555555554, 95% CI = (-0.18156945147644632, 1.1622805625875574)
# Remaining: median = -0.1481, mean = -2.008032128514727e-06, 95% CI = (-0.12445963624128796, 0.12445562017703092)
# Ttest_indResult(statistic=1.441079674709992, pvalue=0.15078419417512332)

# %%
compareExpression('CXCL10',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -1.433, mean = -1.2644222222222221, 95% CI = (-1.6072448867817353, -0.9215995576627091)
# Remaining: median = -0.0646, mean = -2.0080321285129434e-06, 95% CI = (-0.12446020011993367, 0.12445618405567663)
# Ttest_indResult(statistic=-3.7619153801001946, pvalue=0.00020905174560858028)

# %%
compareExpression('CXCL11',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.0789, mean = -0.26669999999999994, 95% CI = (-0.6684361218102362, 0.13503612181023628)
# Remaining: median = -0.0556, mean = -1.6064257028092845e-06, 95% CI = (-0.12445983571338456, 0.12445662286197895)
# Ttest_indResult(statistic=-0.7921881450971583, pvalue=0.42898444233324473)

# %%
compareExpression('AGTR1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.0508, mean = 0.12948888888888888, 95% CI = (-0.1307187143626582, 0.38969649214043595)
# Remaining: median = -0.2605, mean = 4.0160642568760733e-07, 95% CI = (-0.12445733240726434, 0.1244581356201157)
# Ttest_indResult(statistic=0.3859748509657221, pvalue=0.6998358623317923)

# %%
compareExpression('BSG',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.6097, mean = 0.034844444444444456, 95% CI = (-1.037394618233089, 1.107083507121978)
# Remaining: median = 0.0265, mean = 0.0, 95% CI = (-0.12445756868196209, 0.12445756868196209)
# Ttest_indResult(statistic=0.09989478124790534, pvalue=0.920506042843585)
