# %%
from ipynb.fs.full.CovidReceptorExpressionAnalysis_Functions import *

# %%
c1_patients = pd.read_csv('c2.txt',header=None)[0].tolist()
c2_patients = pd.read_csv('c5.txt',header=None)[0].tolist()

for i in range(len(c1_patients)):
    c1_patients[i] = ('TARGET-30-' + c1_patients[i])
for i in range(len(c2_patients)):
    c2_patients[i] = ('TARGET-30-' + c2_patients [i])

c1_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c1_patients)]['Sample Identifier']
c2_samples = clinical_sample_trimmed.loc[clinical_sample_trimmed['#Patient Identifier'].isin(c2_patients)]['Sample Identifier']

# %%
compareEFS([c1_samples,c2_samples], 'EFS stratified by GSEA rank clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median EFS = 1086.0, mean EFS = 1740.212765957447, 95% CI = (1306.5559557997856, 2173.8695761151084)
# Remaining: median EFS = 684.0, mean EFS = 1616.3725490196077, 95% CI = (1181.926063344907, 2050.8190346943084)
# Ttest_indResult(statistic=0.394720455235907, pvalue=0.6939247957291154)

# %%
kaplanmeierEFS([c1_samples,c2_samples], 'Cluster', 'Remaining')

# %%
compareExpression('ACE2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.44675, mean = -0.5061249999999999, 95% CI = (-0.730196535874539, -0.2820534641254609)
# Remaining: median = 0.0903, mean = 0.048088235294117675, 95% CI = (-0.20646662926779522, 0.30264309985603055)
# Ttest_indResult(statistic=-3.187738422530653, pvalue=0.0019303477883451047)

# %%
compareExpression('TMPRSS2',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.20365, mean = -0.3160625, 95% CI = (-0.5103124909361972, -0.12181250906380284)
# Remaining: median = 0.0038, mean = 0.10586274509803924, 95% CI = (-0.22431854293228254, 0.436044033128361)
# Ttest_indResult(statistic=-2.12534247872674, pvalue=0.036098451571814044)

# %%
compareExpression('IFITM2', [c1_samples,c2_samples], 'Clusters', 'Cluster', 'Remaining')
# Out:
# Cluster: median = 0.4882, mean = 0.5666354166666667, 95% CI = (0.3830215530190729, 0.7502492803142605)
# Remaining: median = -0.4503, mean = -0.38612941176470594, 95% CI = (-0.5551288755173883, -0.21712994801202354)
# Ttest_indResult(statistic=7.495083873321544, pvalue=3.123332306419975e-11)

# %%
compareExpression('IFITM3',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.42805, mean = 0.46456041666666675, 95% CI = (0.2949804525245785, 0.634140380808755)
# Remaining: median = -0.3783, mean = -0.3368607843137255, 95% CI = (-0.5343005033548465, -0.1394210652726045)
# Ttest_indResult(statistic=6.001891114670692, pvalue=3.373074050354478e-08)

# %%
compareExpression('MYCN',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.46575, mean = -0.38255833333333333, 95% CI = (-0.5311407531606013, -0.23397591350606542)
# Remaining: median = -0.3081, mean = -0.24203725490196082, 95% CI = (-0.3916666209360161, -0.09240788886790552)
# Ttest_indResult(statistic=-1.3046106641434612, pvalue=0.1951122825884508)

# %%
compareExpression('NTRK1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.08954999999999999, mean = 0.04232291666666666, 95% CI = (-0.1464040993929538, 0.2310499327262871)
# Remaining: median = 0.5637, mean = 0.5795529411764706, 95% CI = (0.350554239693769, 0.8085516426591722)
# Ttest_indResult(statistic=-3.5244986901716966, pvalue=0.0006492494069861354)

# %%
compareExpression('PTPN6',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.7895, mean = 0.8929, 95% CI = (0.6521559382091198, 1.1336440617908803)
# Remaining: median = -0.3639, mean = -0.2903058823529412, 95% CI = (-0.48469026722577435, -0.09592149748010806)
# Ttest_indResult(statistic=7.5364873908347025, pvalue=2.5572639189532576e-11)

# %%
compareExpression('TP53',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.3415, mean = -0.2413875, 95% CI = (-0.4590845224405254, -0.02369047755947462)
# Remaining: median = -0.4811, mean = -0.4003019607843137, 95% CI = (-0.6025789797378966, -0.19802494183073072)
# Ttest_indResult(statistic=1.0495060589216751, pvalue=0.2965530966492339)

# %%
compareExpression('CXCL10',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.7029000000000001, mean = 0.7918854166666666, 95% CI = (0.5609043699723376, 1.0228664633609956)
# Remaining: median = -0.4815, mean = -0.3550901960784314, 95% CI = (-0.5956382623920129, -0.11454212976484993)
# Ttest_indResult(statistic=6.726332555164083, pvalue=1.2121857870101803e-09)

# %%
compareExpression('CXCL11',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = 0.6448, mean = 0.5060604166666666, 95% CI = (0.1988211765090041, 0.813299656824329)
# Remaining: median = -0.1827, mean = -0.16431960784313726, 95% CI = (-0.3975211357121812, 0.06888192002590665)
# Ttest_indResult(statistic=3.431609246775081, pvalue=0.0008832491874503499)

# %%
compareExpression('AGTR1',[c1_samples,c2_samples],'Clusters','Cluster','Remaining')
# Out:
# Cluster: median = -0.6675500000000001, mean = -0.46198958333333334, 95% CI = (-0.6832407811694738, -0.24073838549719284)
# Remaining: median = -0.3314, mean = 0.028405882352941166, 95% CI = (-0.2691135765075983, 0.32592534121348066)
# Ttest_indResult(statistic=-2.5674253934441094, pvalue=0.011772909108425114)
